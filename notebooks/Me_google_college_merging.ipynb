# %%
import pandas as pd
import numpy as np

# %%
me = pd.read_csv('../data/all_institutions_live.csv',engine = 'python')
googledata = pd.read_csv('../data/googledata_cleaned.csv',index_col=0)

# %%
me['address'] = me['address_line1'] + ' ' + me['address_line2']

# %%
me.drop(['address_line1','address_line2'],axis=1,inplace=True)

# %%
googledata.head(2)
# Out:
#    0      1                            2  \
# 0  0   C100  ChIJM7k39sBPXDkRiU6Om4PD_e8
# 1  1  C1000  ChIJqWdamTTKWTkRia51FA2_j4g
#
#                                                    3              4  \
# 0       SPCE Campus, Visnagar, Gujarat 384315, India  02765 225 505
# 1  Yogidham Gurukul, Kalawad Road, Maruti Nagar, ...  0281 256 2681
#
#                   5                                     6    7  8  \
# 0  +91 2765 225 505  Manish Institute of Computer Studies  5.0  2
# 1  +91 281 256 2681  Shree M. & N. Virani Science College  4.5  5
#
#                          9                                                 10  \
# 0  http://mcavisnagar.org/  https://maps.google.com/?cid=17293193114190499465
# 1       http://vsc.edu.in/   https://maps.google.com/?cid=9840293773726559881
#
#           11         12                   13                   14  null_count
# 0  23.683418  72.547188  2018-04-03 08:02:41  2018-04-03 16:12:34          -1
# ...

# %%
me.head(2)
# Out:
#      cid                                               name  \
# 0   C100               Manish Institute of Computer Studies
# 1  C1000  VIRANI SCI. & SHRI YOGIJI MAHARAJ ARTS, COMMER...
#
#                                     city  \
# 0                        Visnagar-384315
# 1  Rajkot, Tehsil - Rajkot, Pin - 360005
#
#                  Affiliated_to_University    state  pin_code  area  \
# 0  Sankalchand Patel University, Visnagar  Gujarat    384315   2.5
# 1           Saurashtra University, Rajkot  Gujarat    360005  23.5
#
#                website  year_of_establishment scholarship_id  \
# 0  www.mcavisnagar.org                 2002.0         117985
# 1       www.vsc.edu.in                 1968.0          85046
#
#                          ...                         solar_power_generation  \
# 0                        ...                                          False
# 1                        ...                                           True
#
# ...
