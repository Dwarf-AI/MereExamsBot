# %%
import pandas as pd
import re
import dask.dataframe as dd
from dask.multiprocessing import get
from tqdm import tqdm

# %%
def syn_gen(col_name):
    if col_name == 'nan':
        return ['nan']
    col_name = col_name.lower()
    name = col_name.split(',')[0]
    names = []
    names.append(name)                                           # As given
    
    name = re.subn('of|\sand|&', '', name, flags = re.IGNORECASE)[0]
    
    name = re.subn('\s+', ' ', name)[0]                          # Removing 'of' and 'and'
    names.append(name)
    names.append(''.join([word[0] for word in name.split()]).upper())
    
    if "'" in col_name:    
        names.append(''.join([word[0] for word in filter(None,re.split('\W+', name))]).upper())
    if col_name.count('.') > 1:
        names.append(''.join(re.split(r'\.\s?', col_name)[:-1]).upper())
        
        try:
            pattern = re.compile('\s?univ\S*\s?|\s?coll\S*\s?|\s?inst\S*\s?|\sres\S*\sfound\S*\s?')
            inst_type = pattern.findall(name)[0]
            names.append(names[-1]+inst_type)
        except:
            pass
        
    if ',' in col_name:
        location_full = [name+re.findall(',.*', col_name)[0][1:] for name in names]
        try:
            location_short = [name+col_name.split(',')[-1].split()[0][0].upper() for name in filter(lambda x: x.isupper(), names)]
            location_short.extend([name+'-'+col_name.split(',')[-1].split()[0][0].upper() for name in filter(lambda x: x.isupper(), names)])
            location_short.extend([name+'/'+col_name.split(',')[-1].split()[0][0].upper() for name in filter(lambda x: x.isupper(), names)])
            location_short.extend([name+' '+col_name.split(',')[-1].split()[0][0].upper() for name in filter(lambda x: x.isupper(), names)])
            names.extend(location_short)
        except:
            pass
        names.extend(location_full)
    return list(set(names))

syn_gen("T.M. Bhagalpur University, Bhagalpur")
# Out:
# ['TM-B',
#  'TM university bhagalpur',
#  'TBU',
#  'TM university',
#  'TBU-B',
#  'TBU B',
#  'TBUB',
#  't.m. bhagalpur university bhagalpur',
#  'TM/B',
#  'TM B',
#  'TM',
#  't.m. bhagalpur university',
#  'TBU bhagalpur',
#  'TMB',
#  'TBU/B',
#  'TM bhagalpur']

# %%
data = pd.read_csv('../all_institutions.csv').astype(str)
# ddata = dd.from_pandas(data['name'], npartitions=2)
# data['col_synonyms'] = ddata.map_partitions(lambda df: df.apply(syn_gen), meta=pd.DataFrame).compute(get=get)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.to_csv('../col_synonym_data.csv')

# %%
data['col_name'] = data['name'].apply(syn_gen)

# %%
entity = 'name'
data = pd.read_csv('../all_colleges_mereexams.csv')#.loc[:,entity]
data[data['name'].isin(data['name'][data['name'].duplicated()])].sort_values("name")# data.shape

# %%
univ_name_synonyms = []
univ_names = data['Affiliated_to_University'].unique()
for name in tqdm(univ_names):
    print(name,syn_gen(name), sep = '\t', end='\n\n')
# Out:
# 100%|██████████| 299/299 [00:00<00:00, 7506.60it/s]
# Sankalchand Patel University, Visnagar	['sankalchand patel university visnagar', 'SPU-V', 'SPUV', 'SPU/V', 'SPU', 'SPU visnagar', 'sankalchand patel university', 'SPU V']
#
# Rani Channamma University, Belagavi	['RCU', 'RCUB', 'rani channamma university', 'rani channamma university belagavi', 'RCU/B', 'RCU B', 'RCU belagavi', 'RCU-B']
#
# Saurashtra University, Rajkot	['SU', 'SU/R', 'SU-R', 'SU rajkot', 'saurashtra university', 'saurashtra university rajkot', 'SUR', 'SU R']
#
# BHAKTA KAVI NARSINH MEHTA UNIVERSITY	['BKNMU', 'bhakta kavi narsinh mehta university']
#
# R K University, Rajkot	['RKU', 'RKU R', 'RKUR', 'r k university', 'RKU-R', 'RKU/R', 'RKU rajkot', 'r k university rajkot']
#
# SWARNIM GUJARAT SPORTS UNIVERSITY	['swarnim gujarat sports university', 'SGSU']
#
# Gujarat Technological University, Ahmedbabd	['gujarat technological university', 'GTU/A', 'GTU ahmedbabd', 'GTU', 'GTU-A', 'GTUA', 'GTU A', 'gujarat technological university ahmedbabd']
#
# SWAMI RAMA HIMALAYAN UNIVERSITY	['SRHU', 'swami rama himalayan university']
#
# VINAYAKA MISSIONs RESEARCH FOUNDATION, SALEM	['vinayaka missions research foundation', 'VMRF', 'vinayaka missions research foundation salem', 'VMRF S', 'VMRFS', 'VMRF-S', 'VMRF/S', 'VMRF salem']
#
# North Maharashtra University, Jalgaon	['north maharashtra university jalgaon', 'NMU J', 'NMUJ', 'NMU/J', 'north maharashtra university', 'NMU', 'NMU-J', 'NMU jalgaon']
#
# Dr Rajendra Prasad Central Agricultural University, Samastipur	['DRPCAUS', 'DRPCAU-S', 'dr rajendra prasad central agricultural university', 'DRPCAU S', 'DRPCAU', 'dr rajendra prasad central agricultural university samastipur', 'DRPCAU/S', 'DRPCAU samastipur']
#
# I K Gujral Punjab Technical University, Jalandhar	['IKGPTU jalandhar', 'IKGPTU', 'IKGPTU/J', 'IKGPTUJ', 'i k gujral punjab technical university', 'IKGPTU-J', 'IKGPTU J', 'i k gujral punjab technical university jalandhar']
#
# MAHARAJA RANJIT SINGH STATE TECHNICAL UNIVERSITY	['MRSSTU', 'maharaja ranjit singh state technical university']
#
# CHAUDHARY RANBIR SINGH UNIVERSITY, JIND	['chaudhary ranbir singh university jind', 'CRSUJ', 'CRSU-J', 'CRSU jind', 'chaudhary ranbir singh university', 'CRSU/J', 'CRSU J', 'CRSU']
#
# Kurukshetra University, Kurukshetra	['KU/K', 'kurukshetra university', 'kurukshetra university kurukshetra', 'KU', 'KU K', 'KU kurukshetra', 'KU-K', 'KUK']
#
# Lakshmibai National Institute of Physical Education, Gwalior	['LNIPE gwalior', 'lakshmibai national institute of physical education gwalior', 'LNIPE/G', 'lakshmibai national institute of physical education', 'LNIPEG', 'LNIPE', 'LNIPE-G', 'LNIPE G', 'lakshmibai national institute physical education', 'lakshmibai national institute physical education gwalior']
#
# Integral University, Lucknow	['IU', 'IU/L', 'integral university lucknow', 'IUL', 'IU lucknow', 'integral university', 'IU-L', 'IU L']
#
# North Orissa University, Mayurbhanj	['NOU mayurbhanj', 'NOU', 'NOU M', 'NOUM', 'NOU-M', 'north orissa university', 'NOU/M', 'north orissa university mayurbhanj']
#
# Shivaji University, Kolhapur	['SU', 'SU K', 'SU kolhapur', 'shivaji university', 'shivaji university kolhapur', 'SUK', 'SU-K', 'SU/K']
#
# Shree Somnath Sanskrit University, Junagarh	['shree somnath sanskrit university junagarh', 'SSSU', 'shree somnath sanskrit university', 'SSSU-J', 'SSSU J', 'SSSUJ', 'SSSU/J', 'SSSU junagarh']
#
# Himachal Pradesh University , Shimla	['HPU S', 'HPU shimla', 'himachal pradesh university ', 'HPUS', 'himachal pradesh university  shimla', 'HPU', 'HPU-S', 'HPU/S']
#
# Himachal Pradesh Technical University, Hamirpur	['himachal pradesh technical university hamirpur', 'HPTU/H', 'HPTU', 'HPTU-H', 'himachal pradesh technical university', 'HPTU H', 'HPTU hamirpur', 'HPTUH']
#
# Sardar Patel University, Vallabh Vidyanagar	['SPU-V', 'SPUV', 'sardar patel university vallabh vidyanagar', 'SPU/V', 'SPU', 'sardar patel university', 'SPU V', 'SPU vallabh vidyanagar']
#
# Mahatma Gandhi University, Kottayam	['mahatma gandhi university', 'mahatma gandhi university kottayam', 'MGU-K', 'MGU', 'MGU/K', 'MGUK', 'MGU K', 'MGU kottayam']
#
# A P J ABDUL KALAM TECHNOLOGICAL UNIVERSITY	['APJAKTU', 'a p j abdul kalam technological university']
#
# KERALA UNIVERSITY OF HEALTH AND ALLIED SCIENCES	['kerala university health allied sciences', 'KUHAS', 'kerala university of health and allied sciences']
#
# GLS UNIVERSITY	['GU', 'gls university']
#
# PARUL UNIVERSITY	['parul university', 'PU']
#
# Calcutta University, Kolkata	['calcutta university', 'CUK', 'CU', 'CU K', 'calcutta university kolkata', 'CU/K', 'CU-K', 'CU kolkata']
#
# THE WEST BENGAL UNIVERSITY OF TEARCHERS TRAINING, EDUCATION PLANNING AND ADMINISTRATION	['TWBUTT education planning and administration', 'TWBUTT-E', 'TWBUTT', 'TWBUTTE', 'the west bengal university of tearchers training education planning and administration', 'TWBUTT E', 'the west bengal university tearchers training education planning and administration', 'TWBUTT/E', 'the west bengal university tearchers training', 'the west bengal university of tearchers training']
#
# Chatrapati Sahuji Maharaj Kanpur University, Kanpur	['CSMKU/K', 'chatrapati sahuji maharaj kanpur university', 'CSMKU', 'CSMKU K', 'CSMKU kanpur', 'CSMKU-K', 'chatrapati sahuji maharaj kanpur university kanpur', 'CSMKUK']
#
# ALLAHABAD STATE UNIVERSITY	['ASU', 'allahabad state university']
#
# Vesveswaraiah Technological University, Belgaum	['VTU', 'VTU/B', 'VTU-B', 'VTU B', 'VTUB', 'VTU belgaum', 'vesveswaraiah technological university belgaum', 'vesveswaraiah technological university']
#
# nan	['nan']
#
# Dayalbagh Educational Institute, Agra	['DEI agra', 'dayalbagh educational institute', 'DEI A', 'DEIA', 'dayalbagh educational institute agra', 'DEI/A', 'DEI', 'DEI-A']
#
# Magadh University, Bodh Gaya	['MU bodh gaya', 'MU', 'MU B', 'MU/B', 'magadh university bodh gaya', 'magadh university', 'MU-B', 'MUB']
#
# Jai Narain Vyas University, Jodhpur	['jai narain vyas university jodhpur', 'JNVUJ', 'JNVU-J', 'JNVU J', 'JNVU jodhpur', 'JNVU', 'jai narain vyas university', 'JNVU/J']
#
# Maharishi Dayanand Saraswati University, Ajmer	['MDSU A', 'maharishi dayanand saraswati university ajmer', 'MDSU ajmer', 'MDSU/A', 'maharishi dayanand saraswati university', 'MDSU-A', 'MDSU', 'MDSUA']
#
# Mahatama Jyotiba Phule Rohikhand University, Bareilly	['MJPRU B', 'MJPRU', 'MJPRU bareilly', 'MJPRUB', 'MJPRU/B', 'MJPRU-B', 'mahatama jyotiba phule rohikhand university bareilly', 'mahatama jyotiba phule rohikhand university']
#
# Karnataka Sanskrit University	['karnataka sanskrit university', 'KSU']
#
# Mahatma Gandhi Kashi Vidyapeeth, Varanasi	['MGKV V', 'MGKV', 'MGKV/V', 'MGKV varanasi', 'MGKV-V', 'mahatma gandhi kashi vidyapeeth', 'MGKVV', 'mahatma gandhi kashi vidyapeeth varanasi']
#
# Maharashtra University of Health Sciences, Nashik	['maharashtra university health sciences', 'MUHSN', 'MUHS', 'maharashtra university health sciences nashik', 'MUHS/N', 'maharashtra university of health sciences nashik', 'maharashtra university of health sciences', 'MUHS-N', 'MUHS N', 'MUHS nashik']
#
# SIDDHARTH UNIVERSITY, KAPILVASTU	['siddharth university', 'SU', 'SU K', 'SU kapilvastu', 'SUK', 'siddharth university kapilvastu', 'SU-K', 'SU/K']
#
# Deen Dayal Upadhyay Gorakhpur University, Gorakhpur	['DDUGU G', 'deen dayal upadhyay gorakhpur university', 'DDUGU-G', 'DDUGU', 'deen dayal upadhyay gorakhpur university gorakhpur', 'DDUGUG', 'DDUGU gorakhpur', 'DDUGU/G']
#
# Tamil Nadu Teacher Education University, Chennai	['TNTEU/C', 'tamil nadu teacher education university', 'TNTEU-C', 'TNTEU C', 'tamil nadu teacher education university chennai', 'TNTEU', 'TNTEU chennai', 'TNTEUC']
#
# Ranchi University, Ranchi	['RU-R', 'RU R', 'ranchi university', 'RU/R', 'RU ranchi', 'RU', 'ranchi university ranchi', 'RUR']
#
# Dr. B. R. Ambedkar University, Agra	['DRBR agra', 'DBRAU agra', 'DRBR-A', 'dr. b. r. ambedkar university agra', 'DBRAU', 'DRBRA', 'DBRAU-A', 'DBRAU/A', 'DBRAUA', 'dr. b. r. ambedkar university', 'DRBR/A', 'DRBR university', 'DBRAU A', 'DRBR A', 'DRBR university agra', 'DRBR']
#
# Sri Devraj Urs Acaedmy of Highehr Education and Research, Kolar	['sri devraj urs acaedmy highehr education research kolar', 'sri devraj urs acaedmy of highehr education and research', 'SDUAHER-K', 'SDUAHER', 'SDUAHER K', 'sri devraj urs acaedmy highehr education research', 'SDUAHER/K', 'sri devraj urs acaedmy of highehr education and research kolar', 'SDUAHER kolar', 'SDUAHERK']
#
# Chhattisgarh Swami Vivekanand Technical University, Bhilai	['CSVTU-B', 'CSVTU', 'CSVTU/B', 'CSVTUB', 'chhattisgarh swami vivekanand technical university bhilai', 'CSVTU bhilai', 'chhattisgarh swami vivekanand technical university', 'CSVTU B']
#
# Solapur University, Solapur	['SU', 'SU/S', 'solapur university', 'SUS', 'SU-S', 'SU S', 'SU solapur', 'solapur university solapur']
#
# Veer Bahadur Singh Purvanchal University, Jaunpur	['VBSPUJ', 'VBSPU/J', 'VBSPU J', 'VBSPU-J', 'VBSPU', 'VBSPU jaunpur', 'veer bahadur singh purvanchal university jaunpur', 'veer bahadur singh purvanchal university']
#
# Sri Venkateswara Institute of Medical Sciences, Tirupathi	['SVIMS T', 'SVIMS-T', 'sri venkateswara institute medical sciences', 'SVIMS', 'SVIMST', 'sri venkateswara institute medical sciences tirupathi', 'sri venkateswara institute of medical sciences', 'SVIMS/T', 'sri venkateswara institute of medical sciences tirupathi', 'SVIMS tirupathi']
#
# D.Y. Patil Educational Society , Kolhapur	['DPES kolhapur', 'd.y. patil educational society ', 'DY K', 'DPESK', 'DPES-K', 'DY-K', 'DPES/K', 'DPES K', 'DYK', 'DPES', 'd.y. patil educational society  kolhapur', 'DY kolhapur', 'DY', 'DY/K']
#
# Charotar University of Science & Technology,  Anand	['CUST', 'CUST A', 'charotar university science technology', 'CUST  anand', 'charotar university science technology  anand', 'CUST-A', 'CUSTA', 'CUST/A', 'charotar university of science & technology', 'charotar university of science & technology  anand']
#
# Kavi Kulguru Kalidas Sanskrit Vishwavidyalaya, Ramtek	['KKKSV ramtek', 'KKKSV', 'KKKSV-R', 'KKKSVR', 'KKKSV R', 'KKKSV/R', 'kavi kulguru kalidas sanskrit vishwavidyalaya', 'kavi kulguru kalidas sanskrit vishwavidyalaya ramtek']
#
# Saveetha University, Chennai	['SU', 'SU C', 'SUC', 'SU-C', 'SU/C', 'saveetha university chennai', 'saveetha university', 'SU chennai']
#
# Rajiv Gandhi University, Itanagar	['RGU', 'RGU-I', 'RGU/I', 'RGUI', 'RGU I', 'rajiv gandhi university itanagar', 'RGU itanagar', 'rajiv gandhi university']
#
# North Eastern Hill University, Shillong	['NEHU/S', 'NEHU S', 'north eastern hill university shillong', 'NEHUS', 'north eastern hill university', 'NEHU shillong', 'NEHU', 'NEHU-S']
#
# The West Bengal University of Health Sciences, Kolkata	['TWBUHS K', 'the west bengal university of health sciences kolkata', 'the west bengal university health sciences', 'TWBUHS kolkata', 'the west bengal university of health sciences', 'TWBUHS', 'the west bengal university health sciences kolkata', 'TWBUHS/K', 'TWBUHSK', 'TWBUHS-K']
#
# Homoeopathy University, Jaipur	['HUJ', 'HU/J', 'HU J', 'homoeopathy university', 'HU-J', 'HU jaipur', 'HU', 'homoeopathy university jaipur']
#
# Anna University, Chennai	['AU', 'AUC', 'anna university chennai', 'anna university', 'AU chennai', 'AU/C', 'AU C', 'AU-C']
#
# G.B. Pant Universtiy of Agriculture and Technology, Pantnagar	['GB P', 'g.b. pant universtiy of agriculture and technology pantnagar', 'GPUAT P', 'GPUAT-P', 'GB universtiy ', 'GPUAT/P', 'GB universtiy  pantnagar', 'g.b. pant universtiy agriculture technology pantnagar', 'GPUATP', 'g.b. pant universtiy agriculture technology', 'g.b. pant universtiy of agriculture and technology', 'GPUAT pantnagar', 'GB pantnagar', 'GPUAT', 'GB', 'GBP', 'GB-P', 'GB/P']
#
# UTTARAKHAND UNIVERSITY OF HORTICULTURE AND FORESTRY, BHARSAR	['UUHF bharsar', 'uttarakhand university of horticulture and forestry', 'UUHF', 'UUHF-B', 'UUHFB', 'UUHF B', 'uttarakhand university horticulture forestry bharsar', 'UUHF/B', 'uttarakhand university horticulture forestry', 'uttarakhand university of horticulture and forestry bharsar']
#
# Nagaland University	['nagaland university', 'NU']
#
# Indian Institute of Foreign Trade, Delhi	['indian institute foreign trade delhi', 'indian institute of foreign trade', 'IIFTD', 'IIFT-D', 'IIFT/D', 'indian institute of foreign trade delhi', 'IIFT D', 'IIFT', 'indian institute foreign trade', 'IIFT delhi']
#
# Mangalore University, Mangalore	['MU/M', 'MU', 'MU M', 'mangalore university', 'MU mangalore', 'mangalore university mangalore', 'MU-M', 'MUM']
#
# Jawarharlal Nehru Architecture and Fine Art University Hyderabad	['JNAFAUH', 'jawarharlal nehru architecture and fine art university hyderabad', 'jawarharlal nehru architecture fine art university hyderabad']
#
# Mother Teresa Women's University, Kodaikanal	['MTWU-K', 'MTWU/K', 'MTWUK', 'MTWSU-K', 'MTWSUK', 'MTWSU', 'MTWU', "mother teresa women's university kodaikanal", 'MTWSU kodaikanal', 'MTWU kodaikanal', 'MTWSU/K', "mother teresa women's university", 'MTWSU K', 'MTWU K']
#
# Bhagat Phool Singh  Mahila University, Khanpur Kalan, Sonipat	['BPSMUS', 'bhagat phool singh  mahila university', 'bhagat phool singh mahila university khanpur kalan, sonipat', 'BPSMU/S', 'BPSMU-S', 'bhagat phool singh  mahila university khanpur kalan, sonipat', 'bhagat phool singh mahila university', 'BPSMU khanpur kalan, sonipat', 'BPSMU', 'BPSMU S']
#
# Gauhati University, Guwahati	['gauhati university', 'GU-G', 'GU/G', 'GU', 'GU guwahati', 'gauhati university guwahati', 'GUG', 'GU G']
#
# SRIMANTA SANKARADEVA UNIVERSITY OF HEALTH SCIENCES, GUWAHATI	['SSUHS', 'SSUHSG', 'SSUHS G', 'srimanta sankaradeva university of health sciences guwahati', 'SSUHS-G', 'SSUHS/G', 'srimanta sankaradeva university health sciences', 'srimanta sankaradeva university health sciences guwahati', 'SSUHS guwahati', 'srimanta sankaradeva university of health sciences']
#
# Mysore University, Mysore	['MU/M', 'MU', 'MU M', 'MU mysore', 'mysore university', 'MU-M', 'MUM', 'mysore university mysore']
#
# Bangalore University, Bangalore	['bangalore university bangalore', 'BU/B', 'bangalore university', 'BU bangalore', 'BU-B', 'BUB', 'BU B', 'BU']
#
# T.M. Bhagalpur University, Bhagalpur	['TM-B', 'TM university bhagalpur', 'TBU', 'TM university', 'TBU-B', 'TBU B', 'TBUB', 't.m. bhagalpur university bhagalpur', 'TM/B', 'TM B', 'TM', 't.m. bhagalpur university', 'TBU bhagalpur', 'TMB', 'TBU/B', 'TM bhagalpur']
#
# Davangere University, Davangere	['DUD', 'DU', 'DU D', 'DU-D', 'davangere university', 'davangere university davangere', 'DU/D', 'DU davangere']
#
# Kuvempu University, Shankaraghatta, Shimoga	['KU shankaraghatta, shimoga', 'KU', 'KUS', 'kuvempu university shankaraghatta, shimoga', 'kuvempu university', 'KU/S', 'KU S', 'KU-S']
#
# Veer Narmad South Gujarat University, Surat	['VNSGU/S', 'VNSGU', 'VNSGU S', 'veer narmad south gujarat university surat', 'VNSGU-S', 'VNSGUS', 'VNSGU surat', 'veer narmad south gujarat university']
#
# Jawaharlal Nehru Technological University, Kakinada	['JNTU kakinada', 'JNTU', 'jawaharlal nehru technological university kakinada', 'JNTU/K', 'JNTU-K', 'jawaharlal nehru technological university', 'JNTUK', 'JNTU K']
#
# Ahmedabad University	['ahmedabad university', 'AU']
#
# Rashtrasant Tukadoji Maharaj Nagpur University, Nagpur	['RTMNU N', 'RTMNU', 'rashtrasant tukadoji maharaj nagpur university nagpur', 'RTMNUN', 'RTMNU/N', 'RTMNU nagpur', 'RTMNU-N', 'rashtrasant tukadoji maharaj nagpur university']
#
# GONDWANA UNIVERSITY, GADCHIROLI	['GU-G', 'gondwana university gadchiroli', 'GU/G', 'GU', 'GUG', 'GU gadchiroli', 'gondwana university', 'GU G']
#
# Vidya Sagar University, Midnapore	['VSU-M', 'vidya sagar university', 'VSUM', 'vidya sagar university midnapore', 'VSU/M', 'VSU M', 'VSU midnapore', 'VSU']
#
# Dr. Harisingh Gaur  Vishwavidyalaya, Sagar	['dr. harisingh gaur  vishwavidyalaya', 'DHGV S', 'DHGV sagar', 'DHGV', 'DHGVS', 'DHGV/S', 'dr. harisingh gaur vishwavidyalaya', 'dr. harisingh gaur vishwavidyalaya sagar', 'dr. harisingh gaur  vishwavidyalaya sagar', 'DHGV-S']
#
# MAHARAJA CHHATRASAL BUNDELKHAND UNIVERSITY	['MCBU', 'maharaja chhatrasal bundelkhand university']
#
# Deenbandhu Chhotu Ram University of Science & Technology, Murthal(Sonepat)	['deenbandhu chhotu ram university of science & technology', 'DCRUST/M', 'deenbandhu chhotu ram university science technology', 'deenbandhu chhotu ram university science technology murthal(sonepat)', 'DCRUST M', 'DCRUST', 'DCRUST murthal(sonepat)', 'DCRUSTM', 'deenbandhu chhotu ram university of science & technology murthal(sonepat)', 'DCRUST-M']
#
# NITTE Unversity, Mangalore	['NU/M', 'NU', 'nitte unversity mangalore', 'NU M', 'nitte unversity', 'NUM', 'NU-M', 'NU mangalore']
#
# Hemchandracharya North Gujart University, Patan	['hemchandracharya north gujart university', 'HNGU P', 'HNGU patan', 'HNGU-P', 'hemchandracharya north gujart university patan', 'HNGU/P', 'HNGUP', 'HNGU']
#
# SYMBIOSIS International University, Pune	['SIU P', 'SIU', 'symbiosis international university pune', 'SIU/P', 'SIUP', 'symbiosis international university', 'SIU pune', 'SIU-P']
#
# Kota University, Kota	['KU/K', 'KU', 'kota university kota', 'kota university', 'KU K', 'KU-K', 'KUK', 'KU kota']
#
# Jai Prakash Vishwavidyalaya, Chapra	['JPV C', 'JPV chapra', 'jai prakash vishwavidyalaya chapra', 'JPV-C', 'JPV/C', 'JPV', 'JPVC', 'jai prakash vishwavidyalaya']
#
# Jawaharlal Nehru Technological University, Hyderabad	['JNTU H', 'jawaharlal nehru technological university hyderabad', 'JNTU-H', 'JNTU', 'JNTUH', 'jawaharlal nehru technological university', 'JNTU hyderabad', 'JNTU/H']
#
# Sampurnanand Sanskrit Vishwavidyalaya,  Varanasi	['SSVV', 'SSV', 'SSV-V', 'SSV V', 'sampurnanand sanskrit vishwavidyalaya  varanasi', 'SSV  varanasi', 'SSV/V', 'sampurnanand sanskrit vishwavidyalaya']
#
# Banaras Hindu University, Banaras	['BHUB', 'BHU', 'banaras hindu university', 'banaras hindu university banaras', 'BHU banaras', 'BHU/B', 'BHU-B', 'BHU B']
#
# Uttrakhand Technical University, Dehradun	['UTUD', 'UTU/D', 'UTU-D', 'UTU D', 'UTU dehradun', 'uttrakhand technical university', 'uttrakhand technical university dehradun', 'UTU']
#
# Fakir Mohan University, Balasore	['FMU', 'FMU/B', 'FMU balasore', 'FMU-B', 'FMU B', 'fakir mohan university balasore', 'fakir mohan university', 'FMUB']
#
# University of Kashmir, Srinagar	['university kashmir srinagar', 'university of kashmir', 'UKS', 'UK/S', 'university of kashmir srinagar', 'UK', 'UK-S', 'UK srinagar', 'university kashmir', 'UK S']
#
# Satavahana University, Karimnagar	['SU', 'SU K', 'satavahana university karimnagar', 'SUK', 'SU karimnagar', 'SU-K', 'satavahana university', 'SU/K']
#
# Gulbarga University, Gulbarga	['GU-G', 'GU/G', 'gulbarga university', 'GU gulbarga', 'GU', 'gulbarga university gulbarga', 'GUG', 'GU G']
#
# DURG UNIVERSITY	['durg university', 'DU']
#
# Pt. Ravishankar Shukla University, Raipur	['pt. ravishankar shukla university', 'PRSU/R', 'PRSUR', 'PRSU-R', 'PRSU R', 'PRSU', 'pt. ravishankar shukla university raipur', 'PRSU raipur']
#
# Ayush and Health Science University of Chattisgarh, Raipur	['AHSUC/R', 'AHSUC-R', 'ayush and health science university of chattisgarh raipur', 'ayush and health science university of chattisgarh', 'ayush health science university chattisgarh', 'AHSUC', 'AHSUCR', 'ayush health science university chattisgarh raipur', 'AHSUC R', 'AHSUC raipur']
#
# Kumaun University, Nainital	['KUN', 'KU', 'KU/N', 'KU-N', 'kumaun university nainital', 'KU N', 'kumaun university', 'KU nainital']
#
# Palamuru University,  Mahabubnagar	['PU/M', 'palamuru university  mahabubnagar', 'PU M', 'palamuru university', 'PU', 'PUM', 'PU  mahabubnagar', 'PU-M']
#
# Sri Venkateswara Veterinary University, Tirupathi	['SVVU', 'sri venkateswara veterinary university tirupathi', 'SVVU T', 'SVVU tirupathi', 'SVVU-T', 'sri venkateswara veterinary university', 'SVVUT', 'SVVU/T']
#
# Dr Y S R Horticulture University	['dr y s r horticulture university', 'DYSRHU']
#
# Punjabi University, Patiala	['punjabi university patiala', 'PU patiala', 'PU P', 'PU', 'punjabi university', 'PUP', 'PU/P', 'PU-P']
#
# BILASPUR VISHWAVIDYALAYA	['bilaspur vishwavidyalaya', 'BV']
#
# Ch. Devi Lal University, Sirsa	['ch. devi lal university sirsa', 'CDLU-S', 'CDLU sirsa', 'ch. devi lal university', 'CDLU', 'CDLU S', 'CDLUS', 'CDLU/S']
#
# Jain Vishva Bharati Institute, Nagaur	['JVBI N', 'JVBIN', 'JVBI', 'JVBI/N', 'JVBI-N', 'jain vishva bharati institute nagaur', 'jain vishva bharati institute', 'JVBI nagaur']
#
# Bundelkhand University,  Jhansi	['BU', 'BU J', 'BU  jhansi', 'bundelkhand university', 'BU/J', 'BU-J', 'bundelkhand university  jhansi', 'BUJ']
#
# Aligarh Muslim University, Aligarh	['AMU A', 'AMU aligarh', 'aligarh muslim university', 'AMU/A', 'aligarh muslim university aligarh', 'AMU', 'AMUA', 'AMU-A']
#
# University of Jammu, Jammu Tawi	['UJJ', 'university of jammu jammu tawi', 'university of jammu', 'UJ', 'UJ J', 'UJ-J', 'UJ jammu tawi', 'university jammu', 'university jammu jammu tawi', 'UJ/J']
#
# Krishna Institute of Medical Sciences Deemed University, Karad	['krishna institute medical sciences deemed university karad', 'KIMSDU', 'KIMSDU K', 'krishna institute of medical sciences deemed university karad', 'KIMSDU/K', 'KIMSDUK', 'krishna institute of medical sciences deemed university', 'krishna institute medical sciences deemed university', 'KIMSDU-K', 'KIMSDU karad']
#
# Utkal University of Culture, Bhubaneswar	['utkal university culture', 'utkal university of culture bhubaneswar', 'utkal university of culture', 'UUC-B', 'utkal university culture bhubaneswar', 'UUC bhubaneswar', 'UUC', 'UUC B', 'UUC/B', 'UUCB']
#
# Andhra University, Visakhapatnam	['AU', 'AU visakhapatnam', 'AUV', 'andhra university', 'AU-V', 'AU/V', 'AU V', 'andhra university visakhapatnam']
#
# Adikavi Nannaya University, Rajahmundry, East Godawari	['ANU-E', 'ANU/E', 'ANU', 'adikavi nannaya university', 'ANUE', 'ANU rajahmundry, east godawari', 'ANU E', 'adikavi nannaya university rajahmundry, east godawari']
#
# K.L.E. Academy of Higher Education and Research, Belgaum	['KLE belgaum', 'KLE B', 'KLEB', 'KAHER/B', 'KLE/B', 'k.l.e. academy of higher education and research', 'KAHERB', 'KAHER belgaum', 'KLE-B', 'k.l.e. academy higher education research belgaum', 'KLE', 'k.l.e. academy higher education research', 'k.l.e. academy of higher education and research belgaum', 'KAHER B', 'KAHER-B', 'KAHER']
#
# Rajasthan University of Veterinary and Animal Sciences, Bikaner	['rajasthan university veterinary animal sciences bikaner', 'RUVAS/B', 'RUVAS B', 'RUVAS bikaner', 'RUVAS-B', 'RUVAS', 'rajasthan university of veterinary and animal sciences bikaner', 'rajasthan university veterinary animal sciences', 'RUVASB', 'rajasthan university of veterinary and animal sciences']
#
# Hemwati Nandan Bahuguna Garhwal Univeristy, Srinagar, Garhwal	['hemwati nandan bahuguna garhwal univeristy', 'HNBGU', 'HNBGU srinagar, garhwal', 'hemwati nandan bahuguna garhwal univeristy srinagar, garhwal', 'HNBGU/G', 'HNBGUG', 'HNBGU G', 'HNBGU-G']
#
# Vikram Simhapuri University, Nellore	['vikram simhapuri university nellore', 'VSUN', 'VSU-N', 'VSU N', 'vikram simhapuri university', 'VSU/N', 'VSU', 'VSU nellore']
#
# Assam Agricultural University, Jorhat	['assam agricultural university jorhat', 'AAU jorhat', 'AAU-J', 'AAU J', 'AAUJ', 'AAU', 'AAU/J', 'assam agricultural university']
#
# Dr.B.R.Ambedkar University, Etcherla	['DU-E', 'DU', 'DRBR/E', 'dr.b.r.ambedkar university etcherla', 'DRBRE', 'DU E', 'DRBR-E', 'DRBR university', 'DU etcherla', 'DU/E', 'dr.b.r.ambedkar university', 'DRBR E', 'DRBR etcherla', 'DRBR university etcherla', 'DRBR', 'DUE']
#
# Bastar Vishwavidyalaya, Bastar	['BV', 'bastar vishwavidyalaya bastar', 'bastar vishwavidyalaya', 'BV/B', 'BV bastar', 'BV-B', 'BV B', 'BVB']
#
# Krishna University, Machhlipattanam	['KU machhlipattanam', 'KU M', 'krishna university machhlipattanam', 'KU', 'KU-M', 'krishna university', 'KUM', 'KU/M']
#
# Osmania University, Hyderabad	['OU H', 'osmania university hyderabad', 'OU hyderabad', 'OU', 'OU/H', 'OUH', 'OU-H', 'osmania university']
#
# Dr Sarvepalli Radhakrishnan Rajasthan Ayurved University, Jodhpur	['DSRRAU J', 'DSRRAUJ', 'DSRRAU/J', 'DSRRAU', 'DSRRAU jodhpur', 'dr sarvepalli radhakrishnan rajasthan ayurved university', 'dr sarvepalli radhakrishnan rajasthan ayurved university jodhpur', 'DSRRAU-J']
#
# Rayalaseema, University Kurnool	['R-U', 'R university kurnool', 'R', 'R/U', 'RU', 'rayalaseema', 'rayalaseema university kurnool', 'R U']
#
# Acharya NG Ranga Agricultural University, Guntur	['ANRAU', 'acharya ng ranga agricultural university', 'ANRAUG', 'acharya ng ranga agricultural university guntur', 'ANRAU guntur', 'ANRAU/G', 'ANRAU G', 'ANRAU-G']
#
# Kushabhau Thakre Patrakarita Avam Jansanchar Vishwavidyalaya, Raipur	['KTPAJVR', 'KTPAJV raipur', 'kushabhau thakre patrakarita avam jansanchar vishwavidyalaya', 'KTPAJV-R', 'kushabhau thakre patrakarita avam jansanchar vishwavidyalaya raipur', 'KTPAJV R', 'KTPAJV/R', 'KTPAJV']
#
# Assam University, Silchar	['AU', 'AUS', 'AU S', 'AU/S', 'AU silchar', 'assam university', 'AU-S', 'assam university silchar']
#
# Kannada University, Hampi, Kamalapura	['KU/K', 'KU hampi, kamalapura', 'KU', 'kannada university hampi, kamalapura', 'kannada university', 'KU K', 'KU-K', 'KUK']
#
# Tumkur University, Tumkur	['TU/T', 'TU-T', 'tumkur university tumkur', 'TU tumkur', 'TUT', 'tumkur university', 'TU T', 'TU']
#
# Central Agricultural University, Imphal	['CAU', 'central agricultural university', 'CAU I', 'CAU/I', 'central agricultural university imphal', 'CAUI', 'CAU imphal', 'CAU-I']
#
# Jawaharlal Nehru Technological University, Anantapur	['JNTUA', 'JNTU', 'jawaharlal nehru technological university anantapur', 'JNTU A', 'jawaharlal nehru technological university', 'JNTU/A', 'JNTU anantapur', 'JNTU-A']
#
# Rashtriya Sanskrit Sansthan, New Delhi	['RSS/N', 'RSSN', 'RSS new delhi', 'RSS-N', 'rashtriya sanskrit sansthan new delhi', 'RSS N', 'RSS', 'rashtriya sanskrit sansthan']
#
# Veer Kunwar Singh University, Arrah	['VKSU', 'VKSU-A', 'veer kunwar singh university arrah', 'VKSU A', 'VKSUA', 'VKSU arrah', 'VKSU/A', 'veer kunwar singh university']
#
# Kakatiya University, Warangal	['KUW', 'KU', 'kakatiya university', 'KU/W', 'KU warangal', 'kakatiya university warangal', 'KU W', 'KU-W']
#
# Guru  Jambheshwar University of Science and Technology, Hissar	['GJUST/H', 'GJUSTH', 'guru jambheshwar university science technology', 'guru  jambheshwar university of science and technology', 'GJUST H', 'guru jambheshwar university science technology hissar', 'GJUST hissar', 'GJUST', 'GJUST-H', 'guru  jambheshwar university of science and technology hissar']
#
# Sri Venkateswara University, Tirupathy	['sri venkateswara university', 'SVU', 'SVU/T', 'SVU-T', 'SVUT', 'sri venkateswara university tirupathy', 'SVU tirupathy', 'SVU T']
#
# Guru Nanak Dev University, Amritsar	['guru nanak dev university amritsar', 'GNDU amritsar', 'GNDUA', 'guru nanak dev university', 'GNDU', 'GNDU/A', 'GNDU-A', 'GNDU A']
#
# Maharshi Dayanand University, Rohtak	['MDU/R', 'MDU-R', 'MDUR', 'MDU rohtak', 'maharshi dayanand university rohtak', 'MDU', 'MDU R', 'maharshi dayanand university']
#
# CHAUDHARY BANSI LAL UNIVERSITY	['CBLU', 'chaudhary bansi lal university']
#
# Alagappa University, Alagappa Nagar, Karaikudi	['AU', 'AU-K', 'AUK', 'alagappa university', 'AU K', 'alagappa university alagappa nagar, karaikudi', 'AU/K', 'AU alagappa nagar, karaikudi']
#
# Choudhary Charan Singh University, Meerut	['choudhary charan singh university meerut', 'CCSU-M', 'CCSU', 'CCSUM', 'CCSU meerut', 'CCSU/M', 'choudhary charan singh university', 'CCSU M']
#
# Panjab University,Chandigarh	['PUC', 'PU/C', 'PU', 'PUchandigarh', 'panjab universitychandigarh', 'PU-C', 'PU C', 'panjab university']
#
# Chaudhary Charan Singh Haryana Agricultural University, Hisar	['chaudhary charan singh haryana agricultural university hisar', 'CCSHAU H', 'CCSHAU-H', 'CCSHAUH', 'CCSHAU', 'chaudhary charan singh haryana agricultural university', 'CCSHAU hisar', 'CCSHAU/H']
#
# Jawaharlal Nehru Krishi Vishwavidyalaya, Jabalpur	['JNKV jabalpur', 'JNKV', 'JNKVJ', 'jawaharlal nehru krishi vishwavidyalaya jabalpur', 'JNKV J', 'jawaharlal nehru krishi vishwavidyalaya', 'JNKV/J', 'JNKV-J']
#
# Raja Mansingh  Tomar Music & Arts University, Gwalior	['raja mansingh tomar music arts university', 'RMTMAUG', 'raja mansingh tomar music arts university gwalior', 'RMTMAU', 'raja mansingh  tomar music & arts university', 'raja mansingh  tomar music & arts university gwalior', 'RMTMAU/G', 'RMTMAU G', 'RMTMAU-G', 'RMTMAU gwalior']
#
# Bhupendra Narayan Mandal University, Madhepura	['bhupendra narayan mandal university', 'BNMU madhepura', 'BNMU/M', 'BNMU-M', 'BNMU M', 'bhupendra narayan mandal university madhepura', 'BNMU', 'BNMUM']
#
# Aryabhatta Knoweledge University , Patna	['aryabhatta knoweledge university  patna', 'AKU P', 'AKU-P', 'AKUP', 'AKU', 'AKU patna', 'AKU/P', 'aryabhatta knoweledge university ']
#
# Devi Ahilya Vishwavidyalaya, Indore	['DAV I', 'DAV-I', 'DAV/I', 'DAVI', 'DAV', 'DAV indore', 'devi ahilya vishwavidyalaya indore', 'devi ahilya vishwavidyalaya']
#
# Biju Patnaik University of Technology, Rourkela	['BPUT', 'BPUT rourkela', 'BPUTR', 'biju patnaik university of technology rourkela', 'biju patnaik university of technology', 'BPUT/R', 'BPUT R', 'biju patnaik university technology rourkela', 'biju patnaik university technology', 'BPUT-R']
#
# Karnataka Vetrinary, Animal & Fisheries Science University, Nandinagar	['KV-N', 'karnataka vetrinary', 'KV animal & fisheries science university, nandinagar', 'KVN', 'karnataka vetrinary animal & fisheries science university, nandinagar', 'KV', 'KV/N', 'KV N']
#
# Yogi Vemana University, Kadapa	['YVU', 'yogi vemana university kadapa', 'YVU-K', 'YVU K', 'YVU/K', 'yogi vemana university', 'YVU kadapa', 'YVUK']
#
# Pt. Bhagwat Dayal Sharma University of Health Sciences	['PBDSUHS', 'pt. bhagwat dayal sharma university of health sciences', 'pt. bhagwat dayal sharma university health sciences']
#
# University  of Agricultural Sciences, Dharwad	['university agricultural sciences', 'UAS-D', 'UAS D', 'university  of agricultural sciences', 'UAS/D', 'UASD', 'university agricultural sciences dharwad', 'UAS dharwad', 'university  of agricultural sciences dharwad', 'UAS']
#
# Goa University, Goa	['GU-G', 'GU/G', 'goa university', 'GU goa', 'GU', 'goa university goa', 'GUG', 'GU G']
#
# Sri Krishnadevaraya University, Anantapur	['sri krishnadevaraya university', 'SKU/A', 'sri krishnadevaraya university anantapur', 'SKUA', 'SKU A', 'SKU anantapur', 'SKU-A', 'SKU']
#
# Makhanlal Chaturvedi National University of Journalism and Communication, Bhopal	['MCNUJC-B', 'makhanlal chaturvedi national university journalism communication bhopal', 'MCNUJC B', 'MCNUJCB', 'makhanlal chaturvedi national university of journalism and communication', 'MCNUJC bhopal', 'makhanlal chaturvedi national university of journalism and communication bhopal', 'MCNUJC', 'makhanlal chaturvedi national university journalism communication', 'MCNUJC/B']
#
# Vikram University, Ujjain	['vikram university', 'VU/U', 'vikram university ujjain', 'VU', 'VU ujjain', 'VU-U', 'VU U', 'VUU']
#
# Awadesh Pratap Singh University, Rewa	['APSU-R', 'awadesh pratap singh university rewa', 'APSU rewa', 'APSU', 'awadesh pratap singh university', 'APSU/R', 'APSUR', 'APSU R']
#
# KING GEORGE MEDICAL UNIVERSITY	['king george medical university', 'KGMU']
#
# Acharya Nagarjuna University, Guntur	['ANU guntur', 'ANU-G', 'ANU/G', 'ANU G', 'acharya nagarjuna university guntur', 'ANUG', 'ANU', 'acharya nagarjuna university']
#
# Guru Gobind Singh Indraprastha University	['guru gobind singh indraprastha university', 'GGSIU']
#
# Lalit Narayan Mithila University, Darbhanga	['LNMU D', 'LNMU darbhanga', 'LNMU-D', 'lalit narayan mithila university', 'LNMU', 'LNMUD', 'lalit narayan mithila university darbhanga', 'LNMU/D']
#
# Indira Kala Sangit Vishwavidyalaya, Khairagarh	['IKSV', 'indira kala sangit vishwavidyalaya', 'IKSV-K', 'IKSV K', 'IKSV/K', 'IKSVK', 'IKSV khairagarh', 'indira kala sangit vishwavidyalaya khairagarh']
#
# Mahatma Gandhi University, Nalgonda	['mahatma gandhi university', 'MGUN', 'MGU', 'mahatma gandhi university nalgonda', 'MGU/N', 'MGU-N', 'MGU N', 'MGU nalgonda']
#
# Indira Gandhi Krishi Vishwavidyalaya, Raipur	['IGKV-R', 'IGKV', 'IGKV R', 'IGKV raipur', 'IGKVR', 'indira gandhi krishi vishwavidyalaya raipur', 'IGKV/R', 'indira gandhi krishi vishwavidyalaya']
#
# CHHATTISGARH KAMDHENU VISHWAVIDALAYA	['chhattisgarh kamdhenu vishwavidalaya', 'CKV']
#
# Mumbai University Mumbai	['mumbai university mumbai', 'MUM']
#
# Dr. Babasaheb Ambedkar Marathwada University, Aurangabad	['DBAMU/A', 'dr. babasaheb ambedkar marathwada university', 'DBAMU A', 'dr. babasaheb ambedkar marathwada university aurangabad', 'DBAMUA', 'DBAMU', 'DBAMU aurangabad', 'DBAMU-A']
#
# Ramakrishna Mission Vivekananda Educational  and Research Institute, Howrah	['RMVERI', 'RMVERI H', 'ramakrishna mission vivekananda educational  and research institute', 'RMVERI-H', 'ramakrishna mission vivekananda educational research institute', 'RMVERI/H', 'ramakrishna mission vivekananda educational  and research institute howrah', 'RMVERIH', 'RMVERI howrah', 'ramakrishna mission vivekananda educational research institute howrah']
#
# Jagadguru Sri Shivarathreeswara University, Mysore	['JSSU/M', 'JSSU mysore', 'JSSU', 'jagadguru sri shivarathreeswara university mysore', 'JSSU-M', 'jagadguru sri shivarathreeswara university', 'JSSU M', 'JSSUM']
#
# Telangana University, Nizamabad	['telangana university nizamabad', 'TU-N', 'TUN', 'telangana university', 'TU N', 'TU/N', 'TU nizamabad', 'TU']
#
# University  of Agricultural Sciences, Raichur	['UAS-R', 'UASR', 'university agricultural sciences', 'UAS raichur', 'university  of agricultural sciences', 'UAS/R', 'university agricultural sciences raichur', 'university  of agricultural sciences raichur', 'UAS', 'UAS R']
#
# Barkatullah University, Bhopal	['barkatullah university', 'BU/B', 'BU-B', 'BU bhopal', 'BUB', 'barkatullah university bhopal', 'BU B', 'BU']
#
# Bharati Vidyapeeth, Pune	['bharati vidyapeeth', 'BV', 'bharati vidyapeeth pune', 'BV P', 'BVP', 'BV-P', 'BV/P', 'BV pune']
#
# Karnataka University, Dharwad	['KU dharwad', 'KU-D', 'KU D', 'KU', 'KU/D', 'karnataka university dharwad', 'karnataka university', 'KUD']
#
# University  of Horticultural Sciences, Bagalkot	['UHSB', 'UHS', 'university  of horticultural sciences bagalkot', 'UHS-B', 'UHS/B', 'university horticultural sciences', 'UHS B', 'university horticultural sciences bagalkot', 'UHS bagalkot', 'university  of horticultural sciences']
#
# UNIVERSITY OF AGRICULTURAL AND HORTICULTURAL SCIENCES, SHIMOGA	['UAHS', 'university agricultural horticultural sciences', 'UAHS/S', 'university of agricultural and horticultural sciences shimoga', 'university of agricultural and horticultural sciences', 'UAHS-S', 'UAHS shimoga', 'university agricultural horticultural sciences shimoga', 'UAHSS', 'UAHS S']
#
# Bharathidasan University, Tiruchirappalli	['BU tiruchirappalli', 'BUT', 'BU T', 'BU/T', 'bharathidasan university', 'BU-T', 'bharathidasan university tiruchirappalli', 'BU']
#
# Thiruvalluvar Univeristy, Vellore	['TU V', 'TUV', 'thiruvalluvar univeristy', 'thiruvalluvar univeristy vellore', 'TU/V', 'TU vellore', 'TU-V', 'TU']
#
# University of Agricultural Sciences, Bangalore	['UAS-B', 'university agricultural sciences bangalore', 'university agricultural sciences', 'university of agricultural sciences', 'UAS/B', 'UAS bangalore', 'university of agricultural sciences bangalore', 'UAS B', 'UASB', 'UAS']
#
# University of Allahabad, Allahabad	['UAA', 'university of allahabad allahabad', 'university of allahabad', 'UA A', 'UA/A', 'UA', 'university allahabad', 'university allahabad allahabad', 'UA allahabad', 'UA-A']
#
# Sri Siddharatha Acedemy of Higher Education	['sri siddharatha acedemy of higher education', 'SSAHE', 'sri siddharatha acedemy higher education']
#
# Madurai Kamraj University, Madurai	['MKU/M', 'MKU M', 'madurai kamraj university madurai', 'madurai kamraj university', 'MKU-M', 'MKU', 'MKU madurai', 'MKUM']
#
# Maharaja Ganga Singh University, Bikaner	['maharaja ganga singh university', 'MGSU B', 'MGSU/B', 'MGSUB', 'MGSU bikaner', 'MGSU', 'maharaja ganga singh university bikaner', 'MGSU-B']
#
# PANDIT DEENDAYAL UPADHYAYA SHEKHAWATI UNIVERSITY	['PDUSU', 'pandit deendayal upadhyaya shekhawati university']
#
# MAHARAJA SURAJMAL BRIJ UNIVERSITY	['MSBU', 'maharaja surajmal brij university']
#
# Homi Bhabha Natioanal Institute Knowledge Management Group, Mumbai	['homi bhabha natioanal institute knowledge management group mumbai', 'HBNIKMGM', 'homi bhabha natioanal institute knowledge management group', 'HBNIKMG M', 'HBNIKMG-M', 'HBNIKMG/M', 'HBNIKMG mumbai', 'HBNIKMG']
#
# 3	['3']
#
# Berhampur University, Berhampur	['berhampur university berhampur', 'BU/B', 'BU berhampur', 'BU-B', 'BUB', 'berhampur university', 'BU B', 'BU']
#
# RAMA DEVI WOMEN'S UNIVERSITY, BHUBANESWAR	['RDWU/B', "rama devi women's university bhubaneswar", 'RDWU-B', 'RDWU', 'RDWSU-B', 'RDWSU', 'RDWSU bhubaneswar', 'RDWU bhubaneswar', 'RDWSU B', 'RDWSUB', 'RDWSU/B', 'RDWUB', "rama devi women's university", 'RDWU B']
#
# Utkal University, Bhubaneswar	['UU/B', 'UU-B', 'UU', 'UU bhubaneswar', 'utkal university', 'utkal university bhubaneswar', 'UUB', 'UU B']
#
# Mohan Lal Sukhadia University, Uaipur	['mohan lal sukhadia university uaipur', 'MLSU U', 'MLSU', 'mohan lal sukhadia university', 'MLSU uaipur', 'MLSUU', 'MLSU-U', 'MLSU/U']
#
# Tata Institute of Fundamental Research, Mumbai	['TIFRM', 'tata institute of fundamental research mumbai', 'TIFR mumbai', 'TIFR-M', 'TIFR', 'tata institute fundamental research', 'TIFR M', 'tata institute fundamental research mumbai', 'tata institute of fundamental research', 'TIFR/M']
#
# Rajiv Gandhi University of Health Sciences, Bangalore	['rajiv gandhi university health sciences', 'RGUHS/B', 'RGUHS-B', 'rajiv gandhi university health sciences bangalore', 'RGUHS bangalore', 'RGUHS', 'RGUHS B', 'rajiv gandhi university of health sciences', 'RGUHSB', 'rajiv gandhi university of health sciences bangalore']
#
# Sambalpur University, Sambalpur	['SU', 'SU/S', 'sambalpur university sambalpur', 'sambalpur university', 'SUS', 'SU-S', 'SU S', 'SU sambalpur']
#
# Krantiguru Shyamji Krishna Verma Kachchh University, Kachchh	['KSKVKU/K', 'krantiguru shyamji krishna verma kachchh university kachchh', 'krantiguru shyamji krishna verma kachchh university', 'KSKVKU', 'KSKVKU-K', 'KSKVKUK', 'KSKVKU K', 'KSKVKU kachchh']
#
# Bharathiar University, Coimbatore	['BU', 'BU C', 'BU-C', 'bharathiar university coimbatore', 'BU coimbatore', 'BU/C', 'bharathiar university', 'BUC']
#
# Manonmaniam Sundaranar University, Tirunelveli	['MSU tirunelveli', 'MSU-T', 'MSU T', 'MSUT', 'MSU/T', 'MSU', 'manonmaniam sundaranar university', 'manonmaniam sundaranar university tirunelveli']
#
# Savitribai Phule Pune University	['savitribai phule pune university', 'SPPU']
#
# Dr. Ram Manohar Lohia  Awadh University, Faizabad	['DRMLAUF', 'DRMLAU-F', 'dr. ram manohar lohia  awadh university faizabad', 'DRMLAU/F', 'dr. ram manohar lohia  awadh university', 'dr. ram manohar lohia awadh university', 'DRMLAU F', 'DRMLAU', 'DRMLAU faizabad', 'dr. ram manohar lohia awadh university faizabad']
#
# Jadavpur University, Kolkata	['JU kolkata', 'JU', 'JU K', 'JU/K', 'jadavpur university kolkata', 'JUK', 'jadavpur university', 'JU-K']
#
# University of Gour Banga, Malda	['university of gour banga', 'university of gour banga malda', 'UGB/M', 'UGB-M', 'UGBM', 'university gour banga', 'UGB malda', 'university gour banga malda', 'UGB', 'UGB M']
#
# TAMIL NADU FISHERIES UNIVERSITY	['TNFU', 'tamil nadu fisheries university']
#
# Tamilnadu Veterinary & Animal Sciences University, Chennai	['tamilnadu veterinary animal sciences university', 'tamilnadu veterinary & animal sciences university chennai', 'TVASU-C', 'TVASUC', 'TVASU C', 'TVASU', 'tamilnadu veterinary & animal sciences university', 'TVASU/C', 'tamilnadu veterinary animal sciences university chennai', 'TVASU chennai']
#
# Nilamber-Pitamber University, Palamu	['nilamber-pitamber university', 'NU', 'NU palamu', 'NU P', 'NU/P', 'nilamber-pitamber university palamu', 'NUP', 'NU-P']
#
# Sant Gadge Baba Amravati University, Amravati	['SGBAU A', 'sant gadge baba amravati university amravati', 'SGBAU', 'SGBAU/A', 'sant gadge baba amravati university', 'SGBAU-A', 'SGBAUA', 'SGBAU amravati']
#
# Dr. D.Y.Patil Vidyapeeth, Pune	['DRDY-P', 'DRDY/P', 'DRDY', 'DRDY P', 'DDVP', 'dr. d.y.patil vidyapeeth pune', 'DDV pune', 'DRDY pune', 'DDV/P', 'DDV-P', 'DDV', 'DDV P', 'dr. d.y.patil vidyapeeth', 'DRDYP']
#
# Calicut University, Thenhipalem, Malapuram	['CU M', 'CU-M', 'CU', 'CUM', 'calicut university', 'CU/M', 'calicut university thenhipalem, malapuram', 'CU thenhipalem, malapuram']
#
# West Bengal State University, Kolkata	['WBSUK', 'WBSU', 'WBSU kolkata', 'WBSU/K', 'WBSU K', 'west bengal state university kolkata', 'WBSU-K', 'west bengal state university']
#
# Nirma University, Ahmedabad	['NU/A', 'NU', 'nirma university ahmedabad', 'NUA', 'NU ahmedabad', 'nirma university', 'NU A', 'NU-A']
#
# Kolhan University,  West Singhbhum	['KUW', 'KU', 'KU/W', 'kolhan university', 'KU  west singhbhum', 'kolhan university  west singhbhum', 'KU W', 'KU-W']
#
# Dr. Balasaheb Sawant Konkan Krishi Vidyaapeeth,(former Konkan Krishi Vidyapeeth) Ratnagiri	['dr. balasaheb sawant konkan krishi vidyaapeeth', 'DBSKKV-(', 'DBSKKV', 'DBSKKV(', 'DBSKKV(former konkan krishi vidyapeeth) ratnagiri', 'DBSKKV (', 'DBSKKV/(', 'dr. balasaheb sawant konkan krishi vidyaapeeth(former konkan krishi vidyapeeth) ratnagiri']
#
# Kerala University, Thiruvananthapuram	['KUT', 'KU T', 'KU', 'kerala university thiruvananthapuram', 'KU thiruvananthapuram', 'kerala university', 'KU/T', 'KU-T']
#
# Kannur University, Kannur	['KU/K', 'KU', 'kannur university', 'kannur university kannur', 'KU kannur', 'KU K', 'KU-K', 'KUK']
#
# Madras University, Chennai	['MUC', 'madras university chennai', 'MU', 'MU/C', 'MU C', 'MU-C', 'madras university', 'MU chennai']
#
# Maharashtra Animal & Fishery Sciences University, Nagpur	['maharashtra animal fishery sciences university', 'maharashtra animal fishery sciences university nagpur', 'MAFSU N', 'MAFSU', 'MAFSU nagpur', 'maharashtra animal & fishery sciences university', 'MAFSUN', 'MAFSU-N', 'MAFSU/N', 'maharashtra animal & fishery sciences university nagpur']
#
# Kerala Agricultural University, Thrissur	['kerala agricultural university thrissur', 'KAU-T', 'KAU T', 'KAU', 'kerala agricultural university', 'KAUT', 'KAU/T', 'KAU thrissur']
#
# Kalyani University, Kalyani	['KU/K', 'KU', 'KU K', 'KU kalyani', 'KU-K', 'KUK', 'kalyani university', 'kalyani university kalyani']
#
# Shri Jagannath Sanskrit Vishwavidyalaya, Puri	['shri jagannath sanskrit vishwavidyalaya puri', 'shri jagannath sanskrit vishwavidyalaya', 'SJSV puri', 'SJSVP', 'SJSV P', 'SJSV-P', 'SJSV', 'SJSV/P']
#
# Ganpat University, Ganpat Vidyanagar, Kherva	['GU ganpat vidyanagar, kherva', 'GU K', 'ganpat university ganpat vidyanagar, kherva', 'GUK', 'GU-K', 'GU', 'ganpat university', 'GU/K']
#
# Smt. Nathibai Damodar Thackersey Women's Univeristy, Mumbai	['SNDTWU/M', 'SNDTWSUM', "smt. nathibai damodar thackersey women's univeristy mumbai", 'SNDTWSU', 'SNDTWSU M', 'SNDTWU-M', 'SNDTWSU mumbai', 'SNDTWU', 'SNDTWU M', 'SNDTWU mumbai', "smt. nathibai damodar thackersey women's univeristy", 'SNDTWUM', 'SNDTWSU/M', 'SNDTWSU-M']
#
# SHRI GOVIND GURU UNIVERSITY	['shri govind guru university', 'SGGU']
#
# Vinoba Bhave University, Hazaribagh	['VBU-H', 'VBU H', 'vinoba bhave university hazaribagh', 'VBU', 'vinoba bhave university', 'VBU hazaribagh', 'VBU/H', 'VBUH']
#
# Marathwada Agricultural University, Parbhani	['MAU P', 'MAU', 'MAU parbhani', 'MAU/P', 'MAU-P', 'marathwada agricultural university', 'marathwada agricultural university parbhani', 'MAUP']
#
# Dr. Punjarao Deshmukh Krishi Vidyapeeth, Akola	['DPDKVA', 'dr. punjarao deshmukh krishi vidyapeeth akola', 'DPDKV A', 'DPDKV-A', 'DPDKV/A', 'dr. punjarao deshmukh krishi vidyapeeth', 'DPDKV akola', 'DPDKV']
#
# Mahatma Phule Krishi Vidyapeeth, Rahuri	['MPKV R', 'MPKV-R', 'MPKVR', 'mahatma phule krishi vidyapeeth', 'MPKV', 'MPKV rahuri', 'MPKV/R', 'mahatma phule krishi vidyapeeth rahuri']
#
# Burdwan University, Burdwan	['BU/B', 'BU burdwan', 'BU-B', 'BUB', 'burdwan university', 'BU B', 'burdwan university burdwan', 'BU']
#
# Sidho-Kanho Birsa University	['sidho-kanho birsa university', 'SBU']
#
# BANKURA UNIVERSITY, BANKURA	['BU B', 'BU/B', 'BU-B', 'BUB', 'BU bankura', 'bankura university bankura', 'bankura university', 'BU']
#
# KAZI NAZRUL UNIVERSITY, ASANSOL	['KNU A', 'kazi nazrul university', 'KNU-A', 'KNUA', 'kazi nazrul university asansol', 'KNU/A', 'KNU', 'KNU asansol']
#
# Rabindra Bharati University, Kolkata	['RBU-K', 'RBUK', 'RBU/K', 'rabindra bharati university', 'RBU K', 'rabindra bharati university kolkata', 'RBU', 'RBU kolkata']
#
# Shanmugha Arts, Science, Technology & Reserch Academy (SASTRA), Thanjavur	['SA', 'shanmugha arts', 'SA/T', 'shanmugha arts science, technology & reserch academy (sastra), thanjavur', 'SA science, technology & reserch academy (sastra), thanjavur', 'SA-T', 'SA T', 'SAT']
#
# Maulana Abul Kalam Azad University of Technology, West Bengal	['maulana abul kalam azad university technology west bengal', 'MAKAUTW', 'MAKAUT/W', 'maulana abul kalam azad university of technology west bengal', 'MAKAUT west bengal', 'MAKAUT W', 'MAKAUT-W', 'maulana abul kalam azad university technology', 'maulana abul kalam azad university of technology', 'MAKAUT']
#
# MGM Institute of Health Sciences, Navi  Mumbai	['MIHSN', 'MIHS navi  mumbai', 'MIHS/N', 'mgm institute of health sciences', 'mgm institute health sciences', 'MIHS', 'mgm institute of health sciences navi  mumbai', 'MIHS-N', 'mgm institute health sciences navi  mumbai', 'MIHS N']
#
# Tamilnadu Agricultural University, Coimbatore	['TAU', 'TAU/C', 'TAU-C', 'tamilnadu agricultural university coimbatore', 'TAU coimbatore', 'TAUC', 'tamilnadu agricultural university', 'TAU C']
#
# Guru Angad Dev Veterinary & Animal Sciences University, Ludhiana	['GADVASU ludhiana', 'guru angad dev veterinary animal sciences university ludhiana', 'GADVASU L', 'guru angad dev veterinary animal sciences university', 'GADVASUL', 'GADVASU/L', 'GADVASU', 'GADVASU-L', 'guru angad dev veterinary & animal sciences university', 'guru angad dev veterinary & animal sciences university ludhiana']
#
# Vijayanagara Sri Krishnadevaraya University, Bellary	['VSKU', 'VSKUB', 'VSKU B', 'VSKU bellary', 'VSKU/B', 'VSKU-B', 'vijayanagara sri krishnadevaraya university', 'vijayanagara sri krishnadevaraya university bellary']
#
# RAJIV GANDHI UNIVERSITY OF KNOWLEDGE TECHNOLOGIES	['rajiv gandhi university of knowledge technologies', 'rajiv gandhi university knowledge technologies', 'RGUKT']
#
# Swami Ramanand Teerth Marathwada University, Nanded	['SRTMUN', 'swami ramanand teerth marathwada university nanded', 'SRTMU N', 'SRTMU-N', 'swami ramanand teerth marathwada university', 'SRTMU nanded', 'SRTMU/N', 'SRTMU']
#
# Rajmata Vijayaraje Scindia Krishi Vishwa Vidyalaya, Gwalior	['RVSKVV G', 'RVSKVV/G', 'rajmata vijayaraje scindia krishi vishwa vidyalaya', 'RVSKVV', 'RVSKVVG', 'rajmata vijayaraje scindia krishi vishwa vidyalaya gwalior', 'RVSKVV-G', 'RVSKVV gwalior']
#
# Sarguja University, Ambikapur	['SU', 'SUA', 'SU/A', 'SU-A', 'sarguja university', 'SU A', 'sarguja university ambikapur', 'SU ambikapur']
#
# COOCH BEHAR PANCHANAN BARMA UNIVERSITY	['cooch behar panchanan barma university', 'CBPBU']
#
# North Bengal University, Darjeeling	['north bengal university', 'NBUD', 'NBU D', 'north bengal university darjeeling', 'NBU-D', 'NBU darjeeling', 'NBU/D', 'NBU']
#
# Pondicherry Univeristy, Puducherry	['PU P', 'PU', 'PUP', 'PU puducherry', 'PU/P', 'pondicherry univeristy', 'pondicherry univeristy puducherry', 'PU-P']
#
# Sido Kanhu Murmu University, Dumka	['SKMU D', 'SKMUD', 'SKMU-D', 'sido kanhu murmu university dumka', 'SKMU dumka', 'SKMU', 'sido kanhu murmu university', 'SKMU/D']
#
# Tamil Nadu Dr. M.G.R. Medical University , Chennai	['TAMIL NADU DRMGR chennai', 'TAMIL NADU DRMGRC', 'TNDMMU-C', 'TNDMMU C', 'TNDMMU chennai', 'tamil nadu dr. m.g.r. medical university ', 'tamil nadu dr. m.g.r. medical university  chennai', 'TAMIL NADU DRMGR C', 'TAMIL NADU DRMGR', 'TAMIL NADU DRMGR/C', 'TAMIL NADU DRMGR university  chennai', 'TNDMMU/C', 'TAMIL NADU DRMGR-C', 'TNDMMUC', 'TAMIL NADU DRMGR university ', 'TNDMMU']
#
# Uttar Pradesh Technical University, Lucknow	['UPTU L', 'UPTU', 'UPTU lucknow', 'uttar pradesh technical university', 'uttar pradesh technical university lucknow', 'UPTUL', 'UPTU-L', 'UPTU/L']
#
# Manipal Academy of Higher Education, Manipal	['manipal academy of higher education', 'MAHE/M', 'MAHE M', 'manipal academy of higher education manipal', 'MAHE manipal', 'MAHEM', 'MAHE-M', 'MAHE', 'manipal academy higher education', 'manipal academy higher education manipal']
#
# Navsari Agricultural University	['NAU', 'navsari agricultural university']
#
# Rajasthan University of Health Sciences, Jaipur	['RUHSJ', 'RUHS-J', 'RUHS', 'rajasthan university of health sciences jaipur', 'rajasthan university health sciences jaipur', 'RUHS jaipur', 'RUHS J', 'RUHS/J', 'rajasthan university of health sciences', 'rajasthan university health sciences']
#
# Tripura University, Agartala	['tripura university', 'TU-A', 'tripura university agartala', 'TU A', 'TU/A', 'TU agartala', 'TUA', 'TU']
#
# Maulana Mazharul Haque Arabic & Persian University, Patna	['maulana mazharul haque arabic persian university', 'MMHAPU-P', 'maulana mazharul haque arabic & persian university', 'maulana mazharul haque arabic & persian university patna', 'MMHAPU', 'MMHAPUP', 'MMHAPU/P', 'maulana mazharul haque arabic persian university patna', 'MMHAPU P', 'MMHAPU patna']
#
# National Institute of Fashion Technology, Hauz Khas	['national institute of fashion technology hauz khas', 'national institute fashion technology', 'national institute of fashion technology', 'NIFT H', 'NIFT-H', 'NIFT', 'NIFT hauz khas', 'national institute fashion technology hauz khas', 'NIFT/H', 'NIFTH']
#
# Sikkim  University, Gangtok	['SU', 'sikkim  university gangtok', 'sikkim university gangtok', 'SU-G', 'sikkim  university', 'SU/G', 'SUG', 'SU gangtok', 'SU G', 'sikkim university']
#
# Cochin University of Science & Technology, Kochi	['cochin university of science & technology', 'CUST', 'cochin university of science & technology kochi', 'CUST K', 'CUST kochi', 'cochin university science technology', 'CUSTK', 'CUST-K', 'cochin university science technology kochi', 'CUST/K']
#
# Periyar University, Salem	['PU S', 'periyar university salem', 'PUS', 'PU', 'periyar university', 'PU-S', 'PU salem', 'PU/S']
#
# Uttaranchal Sanskrit University, Hardwar	['USU', 'USUH', 'USU-H', 'USU/H', 'uttaranchal sanskrit university hardwar', 'USU H', 'USU hardwar', 'uttaranchal sanskrit university']
#
# Manipur University, Imphal	['MU-I', 'MU imphal', 'MU', 'manipur university', 'MU/I', 'MU I', 'MUI', 'manipur university imphal']
#
# Vinayaka Missions Sikkim University, Tadong	['VMSU', 'vinayaka missions sikkim university tadong', 'VMSU-T', 'VMSU/T', 'VMSU tadong', 'VMSU T', 'VMSUT', 'vinayaka missions sikkim university']
#
# Sri Balajai Vidyapeeth Mahatma Gandhi Medical College, Puducherry	['SBVMGMC puducherry', 'SBVMGMC-P', 'SBVMGMC', 'sri balajai vidyapeeth mahatma gandhi medical college', 'SBVMGMCP', 'SBVMGMC P', 'SBVMGMC/P', 'sri balajai vidyapeeth mahatma gandhi medical college puducherry']
#
# Karnataka State Women University, Bijapur	['karnataka state women university', 'KSWU/B', 'KSWU bijapur', 'KSWU-B', 'KSWU', 'KSWUB', 'KSWU B', 'karnataka state women university bijapur']
#
# Maharaja Krishnakumarsinhji Bhavnagar University	['maharaja krishnakumarsinhji bhavnagar university', 'MKBU']
#
# Gujarat University, Ahmedabad	['gujarat university', 'GU/A', 'gujarat university ahmedabad', 'GU', 'GU A', 'GU-A', 'GU ahmedabad', 'GUA']
#
# ANANT NATIONAL UNIVERSITY	['anant national university', 'ANU']
#
# Vellore Institute of Technology, Vellore	['vellore institute of technology', 'vellore institute technology', 'VITV', 'VIT/V', 'vellore institute of technology vellore', 'VIT', 'vellore institute technology vellore', 'VIT vellore', 'VIT-V', 'VIT V']
#
# Marwadi University	['MU', 'marwadi university']
#
# Maharishi Panini Sanskrit Vishwavidyalaya, Ujjain	['MPSV/U', 'MPSV', 'MPSV U', 'MPSV-U', 'maharishi panini sanskrit vishwavidyalaya', 'MPSV ujjain', 'maharishi panini sanskrit vishwavidyalaya ujjain', 'MPSVU']
#
# Junagadh Agricultural University	['JAU', 'junagadh agricultural university']
#
# Dibrugarh University, Dibrugarh	['DU dibrugarh', 'DUD', 'DU', 'DU D', 'DU-D', 'dibrugarh university', 'dibrugarh university dibrugarh', 'DU/D']
#
# Centurion University of Technology and Management	['CUTM', 'centurion university of technology and management', 'centurion university technology management']
#
# Maulana Azad National Urdu University, Hyderabad	['maulana azad national urdu university hyderabad', 'MANUU-H', 'MANUU/H', 'MANUU H', 'MANUUH', 'MANUU', 'maulana azad national urdu university', 'MANUU hyderabad']
#
# Karnataka State Law University, Hubli	['KSLU', 'KSLU/H', 'KSLU-H', 'karnataka state law university hubli', 'KSLU hubli', 'KSLUH', 'karnataka state law university', 'KSLU H']
#
# Central Univeristy of Kerala, Kasaragod	['central univeristy of kerala', 'CUK', 'CUKK', 'CUK kasaragod', 'CUK/K', 'central univeristy of kerala kasaragod', 'CUK-K', 'CUK K', 'central univeristy kerala', 'central univeristy kerala kasaragod']
#
# SRI DEV SUMAN UTTARAKHAND UNIVERSITY, BADSHAHITHOL, TEHRI	['SDSUU T', 'SDSUUT', 'SDSUU/T', 'sri dev suman uttarakhand university', 'SDSUU', 'sri dev suman uttarakhand university badshahithol, tehri', 'SDSUU badshahithol, tehri', 'SDSUU-T']
#
# Rajasthan Agricultural University, Bikaner	['RAU B', 'RAU-B', 'rajasthan agricultural university', 'RAU', 'RAUB', 'rajasthan agricultural university bikaner', 'RAU bikaner', 'RAU/B']
#
# Sher-e-Kashmir University of Agricultural Science & Technology of Kashmir, Srinagar	['sher-e-kashmir university of agricultural science & technology of kashmir srinagar', 'SUASTKS', 'sher-e-kashmir university agricultural science technology kashmir srinagar', 'sher-e-kashmir university agricultural science technology kashmir', 'SUASTK S', 'SUASTK srinagar', 'SUASTK/S', 'sher-e-kashmir university of agricultural science & technology of kashmir', 'SUASTK-S', 'SUASTK']
#
# Institute of Advanced Studies in Education, Churu	['IASIE C', 'IASIE', 'institute advanced studies in education', 'IASIE/C', 'institute advanced studies in education churu', 'IASIEC', 'institute of advanced studies in education churu', 'IASIE churu', 'institute of advanced studies in education', 'IASIE-C']
#
# Teerthanker Mahaveer University, Moradabad	['TMU M', 'TMUM', 'teerthanker mahaveer university', 'teerthanker mahaveer university moradabad', 'TMU', 'TMU moradabad', 'TMU/M', 'TMU-M']
#
# RAJ RISHI BHARTRIHARI MATSYA UNIVERSITY	['raj rishi bhartrihari matsya university', 'RRBMU']
#
# ASSAM SCIENCE AND TECHNOLOGY UNIVERSITY	['assam science technology university', 'ASTU', 'assam science and technology university']
#
# HEMWATI NANDAN BAHUGUNA MEDICAL EDUCATION UNIVERSITY	['hemwati nandan bahuguna medical education university', 'HNBMEU']
#
# Mizoram University, Aizwal	['MU-A', 'mizoram university', 'mizoram university aizwal', 'MUA', 'MU', 'MU/A', 'MU aizwal', 'MU A']
#
# Gujarat Ayurveda University, Jamnagar	['GAU-J', 'GAU J', 'GAU/J', 'gujarat ayurveda university', 'GAU', 'GAU jamnagar', 'GAUJ', 'gujarat ayurveda university jamnagar']
#
# Dharmsinh Desai univeristy, Nadiad	['DDU/N', 'dharmsinh desai univeristy', 'DDU N', 'DDU nadiad', 'DDUN', 'DDU-N', 'dharmsinh desai univeristy nadiad', 'DDU']
#
# Tamilnadu Physical Education and Sports University, Chennai	['TPESUC', 'tamilnadu physical education and sports university', 'TPESU C', 'tamilnadu physical education and sports university chennai', 'tamilnadu physical education sports university chennai', 'TPESU', 'tamilnadu physical education sports university', 'TPESU chennai', 'TPESU-C', 'TPESU/C']
#
# Shri Mata Vaishno Devi University, Jammu	['shri mata vaishno devi university jammu', 'SMVDU J', 'SMVDU-J', 'SMVDUJ', 'shri mata vaishno devi university', 'SMVDU jammu', 'SMVDU', 'SMVDU/J']
#
# DELHI PHARMACEUTICAL SCIENCES AND RESEARCH UNIVERSITY	['DPSRU', 'delhi pharmaceutical sciences research university', 'delhi pharmaceutical sciences and research university']
#
# Central Institute of Fisheries Education, Fishries University, Mumbai	['central institute of fisheries education', 'CIFE M', 'CIFE', 'central institute fisheries education', 'CIFE-M', 'CIFEM', 'central institute fisheries education fishries university, mumbai', 'central institute of fisheries education fishries university, mumbai', 'CIFE fishries university, mumbai', 'CIFE/M']
#
# Chettinad Academy of Research & Education, Kancheepuram	['CARE K', 'CAREK', 'chettinad academy of research & education', 'CARE-K', 'CARE', 'chettinad academy of research & education kancheepuram', 'chettinad academy research education kancheepuram', 'chettinad academy research education', 'CARE/K', 'CARE kancheepuram']
#
# Anand Agricultural University, Anand	['AAU A', 'anand agricultural university', 'AAU-A', 'AAU/A', 'AAU', 'anand agricultural university anand', 'AAU anand', 'AAUA']
#
# Birla Institute of Technology, Ranchi	['birla institute technology ranchi', 'birla institute of technology ranchi', 'birla institute technology', 'BIT/R', 'BIT-R', 'birla institute of technology', 'BIT ranchi', 'BIT R', 'BIT', 'BITR']
#
# Bihar Agriculture University, Sabour	['BAU S', 'bihar agriculture university sabour', 'BAU/S', 'BAU sabour', 'BAU-S', 'bihar agriculture university', 'BAU', 'BAUS']
#
# Yenepoya University, Mangalore	['YU mangalore', 'yenepoya university', 'YU', 'YU M', 'yenepoya university mangalore', 'YUM', 'YU/M', 'YU-M']
#
# Sikkim Manipal University, Gangtok	['sikkim manipal university', 'SMU/G', 'SMU gangtok', 'SMU G', 'SMU', 'SMUG', 'sikkim manipal university gangtok', 'SMU-G']
#
# Kameshwar Singh Darbhanga Sanskrit Vishwavidyalaya, Darbhanga	['KSDSV/D', 'KSDSV-D', 'KSDSV D', 'KSDSV darbhanga', 'kameshwar singh darbhanga sanskrit vishwavidyalaya darbhanga', 'kameshwar singh darbhanga sanskrit vishwavidyalaya', 'KSDSV', 'KSDSVD']
#
# Pravara Institute of Medical Sciences, Ahmednagar	['PIMS', 'PIMS ahmednagar', 'pravara institute of medical sciences', 'pravara institute medical sciences ahmednagar', 'PIMS A', 'pravara institute of medical sciences ahmednagar', 'PIMS-A', 'pravara institute medical sciences', 'PIMS/A', 'PIMSA']

# %%
univ_name_synonyms
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
