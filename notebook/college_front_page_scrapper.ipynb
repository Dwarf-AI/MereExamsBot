# %% [markdown]
# # Front page scrapper

# %%
from collections import Counter, defaultdict
from bs4 import BeautifulSoup as b
from threading import Thread
from tqdm import tqdm
import requests as r
import pandas as pd
import numpy as np
import re

# %%
streams = defaultdict()
streams['medical'] = pd.read_csv('../Kunal_mereexams/medical/medical_courses.csv')
streams['eng'] = pd.read_csv('../Kunal_mereexams/engineering/courses_all.csv')
streams['law'] = pd.read_csv('../Kunal_mereexams/law/law_courses.csv')
streams['design'] = pd.read_csv('../Kunal_mereexams/design/design_courses.csv')
streams['it'] = pd.read_csv('../Kunal_mereexams/it_colleges/it_list.csv')
streams['hotel'] = pd.read_csv('../Kunal_mereexams/hotel_manag/hotel_list.csv')
streams['pharmacy'] = pd.read_csv('../Kunal_mereexams/pharmacy/pharmacy_courses.csv')
streams['management'] = pd.read_csv('../Kunal_mereexams/management/mang_list.csv')
streams['media'] = pd.read_csv('../Kunal_mereexams/media_journalism/media_courses.csv')

# %%
data = pd.DataFrame(columns=['Id', 'Name','known_as', 'Estd','State', 'City', 'Address', 'ownership','Approved_by','Affilate_to','contact', 'Rank','website', 'score', 'facilities', 'exams', 'faculty', 'facebook', 'twitter', 'youtube', 'wikipedia'])

# %%
res = r.get('https://medicine.careers360.com/colleges/madras-medical-college-chennai')
soup = b(res.content,'html.parser')

# %% [markdown]
# ### About College

# %%
res = r.get('https://engineering.careers360.com/colleges/indian-institute-of-technology-madras')
soup = b(res.content,'html.parser')
lists = soup.find_all('ul',class_='clg-info')
l1 = soup.find_all('ul',class_='clg-info')[0]
lsts = []
for li in l1.findAll('li'):
  lsts.append(li.get_text())
lsts
# Out:
# ['Chennai, Tamil Nadu',
#  'Estd : 1959',
#  'Ownership : Government',
#  'Approved By : UGC']

# %% [markdown]
# ### Facilities

# %%
social = soup.find_all('div', class_='social-icon-left')[0]
urls = []
for li in social.find_all('li'):
    urls.append(li.a['href'])
urls
# Out:
# ['https://www.facebook.com/ReachIITM',
#  'https://twitter.com/iitmadras',
#  'https://www.youtube.com/user/ReachIITM',
#  'https://en.wikipedia.org/wiki/Indian_Institute_of_Technology_Madras']

# %%
facilities = []
facility_list = soup.find('div', class_ = 'facilitylist')
facility_list.find('ul')
for li in facility_list.find_all('li'):
    facilities.append(li.get_text())
facilities
# re.findall(' [A-Z][^A-Z]*', facilities)
# Out:
# ['Boys Hostel',
#  'Girls Hostel',
#  'Gym',
#  'Library',
#  'Sports',
#  'Cafeteria',
#  'Auditorium',
#  'Medical',
#  'WiFi',
#  'IT Infrastructure']

# %% [markdown]
# ### Exams

# %%
ex = soup.find_all(class_='college-admission-table')[0].table.tbody
exams = []
for tr in ex.find_all('tr'):
    exams.append(tr.td.get_text())
exams
# Out:
# ['JEE Advanced', 'GATE']

# %%
res = r.get('https://medicine.careers360.com/colleges/jamia-millia-islamia-new-delhi')
soup = b(res.content,'html.parser')
lists = soup.find_all('ul',class_='clg-info')
lsts = []
l1 = soup.find_all('ul',class_='clg-info')[0]
lsts = []
for li in l1.findAll('li'):
  lsts.append(li.get_text())
lsts
#soup.find_all('div',class_='infoQuestion')[0].get_text()[15:]
# Out:
# ['New Delhi, Delhi',
#  'Estd : 1920',
#  'Ownership : Government',
#  'Approved By : UGC']

# %%
l1 = soup.find_all('ul',class_='clg-info')[0].li
l2 = l1.find_next_siblings('li')
estb = int(l2[0].get_text()[7:])
estb
# Out:
# 1920

# %%
streams[stream].head()
# Out:
#    Unnamed: 0                                                  0   1  \
# 0           0  https://engineering.careers360.com/colleges/ji...   1
# 1           1  https://engineering.careers360.com/colleges/ve...  39
# 2           2  https://engineering.careers360.com/colleges/in...  79
# 3           3  https://engineering.careers360.com/colleges/in...  75
# 4           4  https://engineering.careers360.com/colleges/in...  66
#
#                                                    2
# 0  https://engineering.careers360.com/colleges/ji...
# 1  https://engineering.careers360.com/vellore-ins...
# 2  https://engineering.careers360.com/indian-inst...
# 3  https://engineering.careers360.com/indian-inst...
# 4  https://engineering.careers360.com/indian-inst...

# %%
stream = 'eng'
data[stream] = pd.DataFrame(columns=['Id', 'Name','known_as', 'Estd','State', 'City', 'Address', 'ownership','Approved_by','Affilate_to','contact', 'Rank','website', 'score', 'facilities', 'exams', 'faculty','stream'])
for i in np.arange(10):
    link =  streams[stream].iloc[i,1]
    try:
        res = r.get(link)
    except:
        res = None
    soup = b(res.content, 'html.parser')

    try:
        also_as = soup.find_all('div',class_='infoQuestion')[0].get_text()[15:]
    except:
        also_as = None

    try:
        name = soup.find_all('h1',class_='titleNameCol')[0].get_text()
    except:
        name = None

    l1 = soup.find_all('ul',class_='clg-info')[0]
    lsts = []
    for li in l1.findAll('li'):
        lsts.append(li.get_text())

    try:
        city, state = lsts[0].split(',')
    except:
        city, state = None,None

    chks = ['Estd : ','Ownership : ','Approved By : ','Affiliated To : ',]
#     for lst in lsts[1:]:
#       print(re.sub(chks[0],'',lst))

    estb = None
    ownership = None
    approved_by = None
    affilated_to = None
    chk = False
    for lst in lsts[1:]:
        if chks[0] in lst:
            estb = re.sub(chks[0],'',lst)
            #         print(estb)
            chk = True

#     print(not chk)
    if (not chk):
        estb = None

    chk = False
    for lst in lsts[1:]:
        if chks[1] in lst:
            ownership = re.sub(chks[1],'',lst)
            #         print(ownership)
            chk = True
    if(not chk):
        ownership = None

    chk = False
    for lst in lsts[1:]:
        if chks[2] in lst:
            approved_by = re.sub(chks[2],'',lst)
            chk = True
    if not chk:
        approved_by = None

    chk = False
    for lst in lsts[1:]:
        if chks[3] in lst:
            affilated_to = re.sub(chks[3],'',lst)
            chk = True
    if not chk:
        affilated_to = None

    try:
        add = soup.find_all('div',class_='mapInfoColInner')[0].find('br').next_sibling
    except:
        add = None      

    l3 = soup.find_all('ul',class_='clg-info')[1].li

    try:
        website = l3 = soup.find_all('ul',class_='clg-info')[1].li.get_text()
    except:
        website = None
    try:
        contact = l3 = soup.find_all('ul',class_='clg-info')[1].li.next_sibling.next_sibling.get_text()[10:]
    except:
        contact = None

    try:
        rank = int(str(soup.find_all('div', class_='countBlockRayco')[0].span)[6:7])
    except:
        rank = None   
    try:
        score = float(soup.find_all('div', class_='countBlockRayco')[1].span.get_text())
    except:
        score = None
    try:
        facilities = []
        facility_list = soup.find('div', class_ = 'facilitylist')
        facility_list.find('ul')
        for li in facility_list.find_all('li'):
            facilities.append(li.get_text())
    except:
        None

    try:
        ex = soup.find_all(class_='college-admission-table')[0].table.tbody
        exams = []
        for tr in ex.find_all('tr'):
            exams.append(tr.td.get_text())
    except:
        None
        
    try:
        faculty = int(re.findall(r'\d+',str(re.findall(r'Total Faculty In College: \d+',str(soup))))[0])
    except:
        faculty =  None
        
    social = soup.find_all('div', class_='social-icon-left')[0]
    urls = []
    for li in social.find_all('li'):
        urls.append(li.a['href'])
    face = list(filter(lambda x: 'face' in x, urls))
    twit = list(filter(lambda x: 'twit' in x, urls))
    you = list(filter(lambda x: 'youtube' in x, urls))
    wiki = list(filter(lambda x: 'wiki' in x, urls))
    face, twit, you, wiki = list(map(lambda x: x if len(x) > 0 else None), [face, twit, you, wiki])
#     print([i, name, also_as, estb, state, city, add, ownership, approved_by, affilated_to, contact, rank, website, score, facilities, exams, stream])
    data[stream].loc[i] = [i, name, also_as, estb, state, city, add, ownership, approved_by, affilated_to, contact, rank, website, score, facilities, exams, faculty, stream]

#     ''':streams[stream].shape[0]]'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     376                 result = np.empty(len(values), dtype=object)
# --> 377                 result[:] = values
#     378             except ValueError:
#
# ValueError: could not broadcast input array from shape (6371,17) into shape (6371)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2375             try:
# -> 2376                 value = Series(value)
#    2377             except:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     247                 data = _sanitize_array(data, index, dtype, copy,
# --> 248                                        raise_cast_failure=True)
#     249
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3028         else:
# -> 3029             subarr = _asarray_tuplesafe(data, dtype=dtype)
#    3030
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     379                 # we have a list-of-list
# --> 380                 result[:] = [tuple(x) for x in values]
#     381
#
# ValueError: cannot copy sequence with size 17 to array axis with dimension 6371
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-ef2dd993693a> in <module>()
#       1 stream = 'eng'
# ----> 2 data[stream] = pd.DataFrame(columns=['Id', 'Name','known_as', 'Estd','State', 'City', 'Address', 'ownership','Approved_by','Affilate_to','contact', 'Rank','website', 'score', 'facilities', 'exams', 'stream'], index=range(streams[stream].shape[0]))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2394         """
#    2395
# -> 2396         self._ensure_valid_index(value)
#    2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2376                 value = Series(value)
#    2377             except:
# -> 2378                 raise ValueError('Cannot set a frame with no defined index '
#    2379                                  'and a value that cannot be converted to a '
#    2380                                  'Series')
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
data1
# Out:
#        Id                                              Name       known_as  \
# 0       0    Jindal School of Art and Architecture, Sonipat           None
# 1       1          Vellore Institute of Technology, Vellore            VIT
# 18     NaN             NaN             NaN
# 19     NaN             NaN             NaN
# 20     NaN             NaN             NaN
# 21     NaN             NaN             NaN
# 22     NaN             NaN             NaN
# 23     NaN             NaN             NaN
# 24     NaN             NaN             NaN
# 25     NaN             NaN             NaN
# 26     NaN             NaN             NaN
# 27     NaN             NaN             NaN
# 28     NaN             NaN             NaN
# 29     NaN             NaN             NaN
# ...    ...             ...             ...
# 6341   NaN             NaN             NaN
# 6342   NaN             NaN             NaN
# 6343   NaN             NaN             NaN
# 6344   NaN             NaN             NaN
# 6345   NaN             NaN             NaN
# 6346   NaN             NaN             NaN
# 6347   NaN             NaN             NaN
# 6348   NaN             NaN             NaN
# 6349   NaN             NaN             NaN
# 6350   NaN             NaN             NaN
# 6351   NaN             NaN             NaN
# 6352   NaN             NaN             NaN
# 6353   NaN             NaN             NaN
# 6354   NaN             NaN             NaN
# 6355   NaN             NaN             NaN
# 6356   NaN             NaN             NaN
# 6357   NaN             NaN             NaN
# 6358   NaN             NaN             NaN
# 6359   NaN             NaN             NaN
# 6360   NaN             NaN             NaN
# 6361   NaN             NaN             NaN
# 6362   NaN             NaN             NaN
# 6363   NaN             NaN             NaN
# 6364   NaN             NaN             NaN
# 6365   NaN             NaN             NaN
# 6366   NaN             NaN             NaN
# 6367   NaN             NaN             NaN
# 6368   NaN             NaN             NaN
# 6369   NaN             NaN             NaN
# 6370   NaN             NaN             NaN
#
#                                                 Address   ownership  \
# 0      O.P. Jindal Global University (JGU)  Sonipat ...     Private
# 1                  Vellore - 632014  Tamil Nadu  India      Private
# 2
# IIT P.O.  Chennai 600036  INDIA   Government
# 3           Powai  Mumbai 400 076  Maharashtra  India    Government
# 4
# Hauz Khas  New Delhi-110 016  INDIA   Government
# 5                            Kharagpur India - 721302    Government
# 6                       Kalyanpur  Kanpur-208016 INDIA   Government
# 7
# Shahbad Daulatpur  Main Bawana Road  Delhi-11...  Government
# 8
# Tiruchirappalli - 620015  Tamil Nadu  India.   Government
# 9     SRM Nagar  Kattankulathur - 603203  Kancheepur...     Private
# 10                                                  NaN         NaN
# 11                                                  NaN         NaN
# 12                                                  NaN         NaN
# 13                                                  NaN         NaN
# 14                                                  NaN         NaN
# 15                                                  NaN         NaN
# 16                                                  NaN         NaN
# 17                                                  NaN         NaN
# 18                                                  NaN         NaN
# 19                                                  NaN         NaN
# 20                                                  NaN         NaN
# 21                                                  NaN         NaN
# 22                                                  NaN         NaN
# 23                                                  NaN         NaN
# 24                                                  NaN         NaN
# 25                                                  NaN         NaN
# 26                                                  NaN         NaN
# 27                                                  NaN         NaN
# 28                                                  NaN         NaN
# 29                                                  NaN         NaN
# ...                                                 ...         ...
# 6341                                                NaN         NaN
# 6342                                                NaN         NaN
# 6343                                                NaN         NaN
# 6344                                                NaN         NaN
# 6345                                                NaN         NaN
# 6346                                                NaN         NaN
# 6347                                                NaN         NaN
# 6348                                                NaN         NaN
# 6349                                                NaN         NaN
# 6350                                                NaN         NaN
# 6351                                                NaN         NaN
# 6352                                                NaN         NaN
# 6353                                                NaN         NaN
# 6354                                                NaN         NaN
# 6355                                                NaN         NaN
# 6356                                                NaN         NaN
# 6357                                                NaN         NaN
# 6358                                                NaN         NaN
# 6359                                                NaN         NaN
# 6360                                                NaN         NaN
# 6361                                                NaN         NaN
# 6362                                                NaN         NaN
# 6363                                                NaN         NaN
# 6364                                                NaN         NaN
# 6365                                                NaN         NaN
# 6366                                                NaN         NaN
# 6367                                                NaN         NaN
# 6368                                                NaN         NaN
# 6369                                                NaN         NaN
# 6370                                                NaN         NaN
#
#                                        Approved_by  \
# 0                          Constitutent +1 moreUGC
# 1                                              UGC
# 2                                              UGC
# 3                                              UGC
# 4                                              UGC
# 5                                              UGC
# 6                                              UGC
# 7     UGC +2 moreAICTE, Government of NCT of Delhi
# 8                                              UGC
# 9              UGC +5 moreIOP, MCI, MHRD, DCI, INC
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25                                             NaN
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                             NaN
# ...                                            ...
# 6341                                           NaN
# 6342                                           NaN
# 6343                                           NaN
# 6344                                           NaN
# 6345                                           NaN
# 6346                                           NaN
# 6347                                           NaN
# 6348                                           NaN
# 6349                                           NaN
# 6350                                           NaN
# 6351                                           NaN
# 6352                                           NaN
# 6353                                           NaN
# 6354                                           NaN
# 6355                                           NaN
# 6356                                           NaN
# 6357                                           NaN
# 6358                                           NaN
# 6359                                           NaN
# 6360                                           NaN
# 6361                                           NaN
# 6362                                           NaN
# 6363                                           NaN
# 6364                                           NaN
# 6365                                           NaN
# 6366                                           NaN
# 6367                                           NaN
# 6368                                           NaN
# 6369                                           NaN
# 6370                                           NaN
#
#                                Affilate_to       contact  Rank  \
# 0     OP Jindal Global University, Sonipat  0130-4091800  None
# 1                                     None          None  None
# 2                                     None          None  None
# 3                                     None  022-25722545  None
# 4                                     None  011-26597135  None
# 5                                     None  03222-255221  None
# 6                                     None  0512-2590151  None
# 7                                     None  011-27871018  None
# 8                                     None          None  None
# 9                                     None          None  None
# 10                                     NaN           NaN   NaN
# 11                                     NaN           NaN   NaN
# 12                                     NaN           NaN   NaN
# 13                                     NaN           NaN   NaN
# 14                                     NaN           NaN   NaN
# 15                                     NaN           NaN   NaN
# 16                                     NaN           NaN   NaN
# 17                                     NaN           NaN   NaN
# 18                                     NaN           NaN   NaN
# 19                                     NaN           NaN   NaN
# 20                                     NaN           NaN   NaN
# 21                                     NaN           NaN   NaN
# 22                                     NaN           NaN   NaN
# 23                                     NaN           NaN   NaN
# 24                                     NaN           NaN   NaN
# 25                                     NaN           NaN   NaN
# 26                                     NaN           NaN   NaN
# 27                                     NaN           NaN   NaN
# 28                                     NaN           NaN   NaN
# 29                                     NaN           NaN   NaN
# ...                                    ...           ...   ...
# 6341                                   NaN           NaN   NaN
# 6342                                   NaN           NaN   NaN
# 6343                                   NaN           NaN   NaN
# 6344                                   NaN           NaN   NaN
# 6345                                   NaN           NaN   NaN
# 6346                                   NaN           NaN   NaN
# 6347                                   NaN           NaN   NaN
# 6348                                   NaN           NaN   NaN
# 6349                                   NaN           NaN   NaN
# 6350                                   NaN           NaN   NaN
# 6351                                   NaN           NaN   NaN
# 6352                                   NaN           NaN   NaN
# 6353                                   NaN           NaN   NaN
# 6354                                   NaN           NaN   NaN
# 6355                                   NaN           NaN   NaN
# 6356                                   NaN           NaN   NaN
# 6357                                   NaN           NaN   NaN
# 6358                                   NaN           NaN   NaN
# 6359                                   NaN           NaN   NaN
# 6360                                   NaN           NaN   NaN
# 6361                                   NaN           NaN   NaN
# 6362                                   NaN           NaN   NaN
# 6363                                   NaN           NaN   NaN
# 6364                                   NaN           NaN   NaN
# 6365                                   NaN           NaN   NaN
# 6366                                   NaN           NaN   NaN
# 6367                                   NaN           NaN   NaN
# 6368                                   NaN           NaN   NaN
# 6369                                   NaN           NaN   NaN
# 6370                                   NaN           NaN   NaN
#
#                         website score  \
# 0           http://jsaa.edu.in/  None
# 1         http://www.vit.ac.in/  None
# 2        http://www.iitm.ac.in/  None
# 3        http://www.iitb.ac.in/  None
# 4         http://www.iitd.ac.in  None
# 5      http://www.iitkgp.ac.in/  None
# 6            http://iitk.ac.in/  None
# 7             http://dtu.ac.in/  None
# 8         https://www.nitt.edu/  None
# 9     http://www.srmuniv.ac.in/  None
# 10                          NaN   NaN
# 11                          NaN   NaN
# 12                          NaN   NaN
# 13                          NaN   NaN
# 14                          NaN   NaN
# 15                          NaN   NaN
# 16                          NaN   NaN
# 17                          NaN   NaN
# 18                          NaN   NaN
# 19                          NaN   NaN
# 20                          NaN   NaN
# 21                          NaN   NaN
# 22                          NaN   NaN
# 23                          NaN   NaN
# 24                          NaN   NaN
# 25                          NaN   NaN
# 26                          NaN   NaN
# 27                          NaN   NaN
# 28                          NaN   NaN
# 29                          NaN   NaN
# ...                         ...   ...
# 6341                        NaN   NaN
# 6342                        NaN   NaN
# 6343                        NaN   NaN
# 6344                        NaN   NaN
# 6345                        NaN   NaN
# 6346                        NaN   NaN
# 6347                        NaN   NaN
# 6348                        NaN   NaN
# 6349                        NaN   NaN
# 6350                        NaN   NaN
# 6351                        NaN   NaN
# 6352                        NaN   NaN
# 6353                        NaN   NaN
# 6354                        NaN   NaN
# 6355                        NaN   NaN
# 6356                        NaN   NaN
# 6357                        NaN   NaN
# 6358                        NaN   NaN
# 6359                        NaN   NaN
# 6360                        NaN   NaN
# 6361                        NaN   NaN
# 6362                        NaN   NaN
# 6363                        NaN   NaN
# 6364                        NaN   NaN
# 6365                        NaN   NaN
# 6366                        NaN   NaN
# 6367                        NaN   NaN
# 6368                        NaN   NaN
# 6369                        NaN   NaN
# 6370                        NaN   NaN
#
#                                              facilities  \
# 0                                                    []
# 1     [Boys Hostel, Girls Hostel, Gym, Library, Spor...
# 2     [Boys Hostel, Girls Hostel, Gym, Library, Spor...
# 3     [Boys Hostel, Girls Hostel, Gym, Library, Spor...
# 4     [Boys Hostel, Girls Hostel, Gym, Library, Spor...
# 5     [Boys Hostel, Girls Hostel, Gym, Library, Spor...
# 6     [Boys Hostel, Girls Hostel, Gym, Library, Spor...
# 7     [Boys Hostel, Girls Hostel, Gym, Library, Spor...
# 8     [Boys Hostel, Girls Hostel, Gym, Library, Spor...
# 9     [Boys Hostel, Girls Hostel, Gym, Library, Spor...
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 6341                                                NaN
# 6342                                                NaN
# 6343                                                NaN
# 6344                                                NaN
# 6345                                                NaN
# 6346                                                NaN
# 6347                                                NaN
# 6348                                                NaN
# 6349                                                NaN
# 6350                                                NaN
# 6351                                                NaN
# 6352                                                NaN
# 6353                                                NaN
# 6354                                                NaN
# 6355                                                NaN
# 6356                                                NaN
# 6357                                                NaN
# 6358                                                NaN
# 6359                                                NaN
# 6360                                                NaN
# 6361                                                NaN
# 6362                                                NaN
# 6363                                                NaN
# 6364                                                NaN
# 6365                                                NaN
# 6366                                                NaN
# 6367                                                NaN
# 6368                                                NaN
# 6369                                                NaN
# 6370                                                NaN
#
#                                        exams stream
# 0                                     [NATA]    eng
# 1               [VITMEE, VITEEE, NATA, GATE]    eng
# 2                       [JEE Advanced, GATE]    eng
# 3         [JEE Advanced, CEED , GATE, UCEED]    eng
# 4                [JEE Advanced, GATE, CEED ]    eng
# 5                       [JEE Advanced, GATE]    eng
# 6                [JEE Advanced, GATE, CEED ]    eng
# 7           [JEE Main, DTU, GATE, JAC Delhi]    eng
# 8                     [JEE Main, GATE, DASA]    eng
# 9     [SRMJEEE, NATA, SRMGEET, GATE, TANCET]    eng
# 10                                       NaN    NaN
# 11                                       NaN    NaN
# 12                                       NaN    NaN
# 13                                       NaN    NaN
# 14                                       NaN    NaN
# 15                                       NaN    NaN
# 16                                       NaN    NaN
# 17                                       NaN    NaN
# 18                                       NaN    NaN
# 19                                       NaN    NaN
# 20                                       NaN    NaN
# 21                                       NaN    NaN
# 22                                       NaN    NaN
# 23                                       NaN    NaN
# 24                                       NaN    NaN
# 25                                       NaN    NaN
# 26                                       NaN    NaN
# 27                                       NaN    NaN
# 28                                       NaN    NaN
# 29                                       NaN    NaN
# ...                                      ...    ...
# 6341                                     NaN    NaN
# 6342                                     NaN    NaN
# 6343                                     NaN    NaN
# 6344                                     NaN    NaN
# 6345                                     NaN    NaN
# 6346                                     NaN    NaN
# 6347                                     NaN    NaN
# 6348                                     NaN    NaN
# 6349                                     NaN    NaN
# 6350                                     NaN    NaN
# 6351                                     NaN    NaN
# 6352                                     NaN    NaN
# 6353                                     NaN    NaN
# 6354                                     NaN    NaN
# 6355                                     NaN    NaN
# 6356                                     NaN    NaN
# 6357                                     NaN    NaN
# 6358                                     NaN    NaN
# 6359                                     NaN    NaN
# 6360                                     NaN    NaN
# 6361                                     NaN    NaN
# 6362                                     NaN    NaN
# 6363                                     NaN    NaN
# 6364                                     NaN    NaN
# 6365                                     NaN    NaN
# 6366                                     NaN    NaN
# 6367                                     NaN    NaN
# 6368                                     NaN    NaN
# 6369                                     NaN    NaN
# 6370                                     NaN    NaN
#
# [6371 rows x 17 columns]

# %%
data['rng']
# Out:
# defaultdict(None,
#             {'medical':        Id                                               Name    known_as  \
#              0       0  All India Institute of Medical Sciences New Delhi       AIIMS
#              1       1            Maulana Azad Medical College, New Delhi  MAMC Delhi
#              2443                                                NaN         NaN
#              2444                                                NaN         NaN
#              2445                                                NaN         NaN
#              2446                                                NaN         NaN
#              2447                                                NaN         NaN
#              2448                                                NaN         NaN
#              2449                                                NaN         NaN
#              2450                                                NaN         NaN
#              2451                                                NaN         NaN
#              2452                                                NaN         NaN
#
#                                                          Approved_by Affilate_to  \
#              0     (MCI) Medical Council of India +3 moreUGC, NCI...        None
#              1                        (MCI) Medical Council of India        None
#              2                                                   UGC        None
#              3             (MCI) Medical Council of India +1 moreINC        None
#              4                                                   UGC        None
#              5                        (MCI) Medical Council of India        None
#              6                                                   NaN         NaN
#              7                                                   NaN         NaN
#              8                                                   NaN         NaN
#              9                                                   NaN         NaN
#              10                                                  NaN         NaN
#              11                                                  NaN         NaN
#              12                                                  NaN         NaN
#              13                                                  NaN         NaN
#              14                                                  NaN         NaN
#              15                                                  NaN         NaN
#              16                                                  NaN         NaN
#              17                                                  NaN         NaN
#              18                                                  NaN         NaN
#              19                                                  NaN         NaN
#              20                                                  NaN         NaN
#              21                                                  NaN         NaN
#              22                                                  NaN         NaN
#              23                                                  NaN         NaN
#              24                                                  NaN         NaN
#              25                                                  NaN         NaN
#              26                                                  NaN         NaN
#              27                                                  NaN         NaN
#              28                                                  NaN         NaN
#              29                                                  NaN         NaN
#              ...                                                 ...         ...
#              2423                                                NaN         NaN
#              2424                                                NaN         NaN
#              2425                                                NaN         NaN
#              2426                                                NaN         NaN
#              2427                                                NaN         NaN
#              2428                                                NaN         NaN
#              2429                                                NaN         NaN
#              2430                                                NaN         NaN
#              2431                                                NaN         NaN
#              2432                                                NaN         NaN
#              2433                                                NaN         NaN
#              2434                                                NaN         NaN
#              2435                                                NaN         NaN
#              2436                                                NaN         NaN
#              2437                                                NaN         NaN
#              2438                                                NaN         NaN
#              2439                                                NaN         NaN
#              2440                                                NaN         NaN
#              2441                                                NaN         NaN
#              2442                                                NaN         NaN
#              2443                                                NaN         NaN
#              2444                                                NaN         NaN
#              2445                                                NaN         NaN
#              2446                                                NaN         NaN
#              2447                                                NaN         NaN
#              2448                                                NaN         NaN
#              2449                                                NaN         NaN
#              2450                                                NaN         NaN
#              2451                                                NaN         NaN
#              2452                                                NaN         NaN
#
#                         contact  Rank                       website   score  \
#              0     011-26588500     1  http://www.aiims.edu/en.html  461.95
#              1     011-23239271     6        http://www.mamc.ac.in/  268.27
#              2             None  None          http://ggsipu.ac.in/    None
#              3             None     7       http://www.afmc.nic.in/  263.81
#              4             None  None             http://jmi.ac.in/    None
#              5     0416-2222102     1  http://www.cmch-vellore.edu/  371.77
#              6              NaN   NaN                           NaN     NaN
#              7              NaN   NaN                           NaN     NaN
#              8              NaN   NaN                           NaN     NaN
#              9              NaN   NaN                           NaN     NaN
#              10             NaN   NaN                           NaN     NaN
#              11             NaN   NaN                           NaN     NaN
#              12             NaN   NaN                           NaN     NaN
#              13             NaN   NaN                           NaN     NaN
#              14             NaN   NaN                           NaN     NaN
#              15             NaN   NaN                           NaN     NaN
#              16             NaN   NaN                           NaN     NaN
#              2431                                                NaN
#              2432                                                NaN
#              2433                                                NaN
#              2434                                                NaN
#              2435                                                NaN
#              2436                                                NaN
#              2437                                                NaN
#              2438                                                NaN
#              2439                                                NaN
#              2440                                                NaN
#              2441                                                NaN
#              2442                                                NaN
#              2443                                                NaN
#              2444                                                NaN
#              2445                                                NaN
#              2446                                                NaN
#              2447                                                NaN
#              2448                                                NaN
#              2449                                                NaN
#              2450                                                NaN
#              2451                                                NaN
#              2452                                                NaN
#
#                                                      exams   stream
#              0     [AIIMS MBBS, AIIMS PG , AIIMS Nursing ]  medical
#              1                          [NEET PG, NEET UG]  medical
#              2                                   [NEET UG]  medical
#              3                          [NEET UG, NEET PG]  medical
#              4                                   [NEET UG]  medical
#              5                          [NEET UG, NEET PG]  medical
#              6                                         NaN      NaN
#              7                                         NaN      NaN
#              8                                         NaN      NaN
#              9                                         NaN      NaN
#              10                                        NaN      NaN
#              11                                        NaN      NaN
#              12                                        NaN      NaN
#              13                                        NaN      NaN
#              14                                        NaN      NaN
#              15                                        NaN      NaN
#              16                                        NaN      NaN
#              17                                        NaN      NaN
#              18                                        NaN      NaN
#              19                                        NaN      NaN
#              20                                        NaN      NaN
#              21                                        NaN      NaN
#              22                                        NaN      NaN
#              23                                        NaN      NaN
#              24                                        NaN      NaN
#              25                                        NaN      NaN
#              26                                        NaN      NaN
#              27                                        NaN      NaN
#              28                                        NaN      NaN
#              29                                        NaN      NaN
#              ...                                       ...      ...
#              2423                                      NaN      NaN
#              2424                                      NaN      NaN
#              2425                                      NaN      NaN
#              2426                                      NaN      NaN
#              2427                                      NaN      NaN
#              2428                                      NaN      NaN
#              2429                                      NaN      NaN
#              2430                                      NaN      NaN
#              2431                                      NaN      NaN
#              2432                                      NaN      NaN
#              2433                                      NaN      NaN
#              2434                                      NaN      NaN
#              2435                                      NaN      NaN
#              2436                                      NaN      NaN
#              2437                                      NaN      NaN
#              2438                                      NaN      NaN
#              2439                                      NaN      NaN
#              2440                                      NaN      NaN
#              2441                                      NaN      NaN
#              2442                                      NaN      NaN
#              2443                                      NaN      NaN
#              2444                                      NaN      NaN
#              2445                                      NaN      NaN
#              2446                                      NaN      NaN
#              2447                                      NaN      NaN
#              2448                                      NaN      NaN
#              2449                                      NaN      NaN
#              2450                                      NaN      NaN
#              2451                                      NaN      NaN
#              2452                                      NaN      NaN
#
#              [2453 rows x 17 columns]})

# %%
data2 = data[stream][0:25]['facilities'].apply(Counter)
data3 = pd.DataFrame.from_records(data2).fillna(value=0)
data3 = data3[list(filter(lambda x: len(x)>1, data3.columns))].astype(int)
# data3 = pd.merge(data, data3, on='id')
data3.head()

# %%
data = defaultdict()
threads = defaultdict()
for stream in ['eng']:#streams.keys():
    threads[stream] = Thread(target=scrapper, args = (stream,))
for stream in ['eng']:#streams.keys():
    threads[stream].start()
for stream in ['eng']:#streams.keys():
    threads[stream].join()
# Out:
# eng not completed correctly

# %%
# Out:
# dict_keys(['eng'])

# %%
temp = defaultdict()

# %%
temp[pd.DAt]
